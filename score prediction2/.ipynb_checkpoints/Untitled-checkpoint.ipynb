# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
from tensorflow.keras.losses import Huber
import joblib

# Load dataset
df = pd.read_csv("final_dataset_with_pitch.csv")

#  ENHANCED FEATURE ENGINEERING

# Sort and compute cumulative metrics
df = df.sort_values(by=['match_id', 'inning', 'over', 'ball'])

# Basic cumulative features
df['cumulative_runs'] = df.groupby(['match_id', 'inning'])['total_runs'].cumsum()
df['cumulative_wickets'] = df.groupby(['match_id', 'inning'])['is_wicket'].cumsum()

# Enhanced features
df['balls_bowled'] = df.groupby(['match_id', 'inning']).cumcount() + 1
df['run_rate'] = df['cumulative_runs'] / (df['over'] + 0.1)  # Avoid division by zero
df['strike_rate'] = df.groupby(['match_id', 'inning', 'batter'])['total_runs'].cumsum() / \
                   df.groupby(['match_id', 'inning', 'batter']).cumcount().add(1)

# Player performance metrics (rolling averages)
for player_col in ['batter', 'bowler']:
    df[f'{player_col}_avg'] = df.groupby(player_col)['total_runs'].transform(
        lambda x: x.expanding().mean().shift(1)
    )

# Phase with more granularity
def get_phase(over):
    if over <= 6:
        return 'Powerplay'
    elif over <= 10:
        return 'Middle1'
    elif over <= 15:
        return 'Middle2'
    else:
        return 'Death'
df['phase'] = df['over'].apply(get_phase)

# Target engineering
final_scores = df.groupby(['match_id', 'inning'])['total_runs'].sum().reset_index()
final_scores.columns = ['match_id', 'inning', 'final_score']
df = pd.merge(df, final_scores, on=['match_id', 'inning'])

# Next over runs with better handling of innings breaks
df['next_over_runs'] = df.groupby(['match_id', 'inning'])['total_runs'].rolling(
    window=6, min_periods=1
).sum().shift(-6).reset_index(level=[0,1], drop=True)

# DATA CLEANING
# Handle missing values
df.fillna({
    'batter_avg': df['total_runs'].mean(),
    'bowler_avg': df['total_runs'].mean(),
    'next_over_runs': 0
}, inplace=True)

# Remove outliers (top/bottom 1%)
for col in ['total_runs', 'cumulative_runs', 'next_over_runs']:
    q1 = df[col].quantile(0.01)
    q99 = df[col].quantile(0.99)
    df = df[(df[col] >= q1) & (df[col] <= q99)]


#  FEATURE SELECTION

features = [
    'venue', 'batting_team', 'bowling_team', 'batter', 'bowler',
    'over', 'cumulative_runs', 'cumulative_wickets', 'phase', 'pitch_type',
    'run_rate', 'strike_rate', 'batter_avg', 'bowler_avg'
]

X = df[features]
y_score = df['final_score']
y_next_over = df['next_over_runs']

#  IMPROVED PREPROCESSING

categorical_features = ['venue', 'batting_team', 'bowling_team', 'batter', 'bowler', 'phase', 'pitch_type']
numeric_features = ['over', 'cumulative_runs', 'cumulative_wickets', 'run_rate', 'strike_rate', 'batter_avg', 'bowler_avg']

preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features),
    ('num', StandardScaler(), numeric_features)
])

#  TRAIN-TEST SPLIT WITH STRATIFICATION

# Stratify by phase to ensure balanced representation
X_train, X_test, y_score_train, y_score_test, y_next_train, y_next_test = train_test_split(
    X, y_score, y_next_over, test_size=0.2, random_state=42, stratify=df['phase']
)

# Fit preprocessor
preprocessor.fit(X_train)
X_train_proc = preprocessor.transform(X_train)
X_test_proc = preprocessor.transform(X_test)

#  ENHANCED MODEL ARCHITECTURE

def build_enhanced_model(input_shape, output_name):
    model = models.Sequential([
        layers.Input(shape=(input_shape,), name='input_layer'),
        layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, name=output_name)
    ])
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss=Huber(),  # Correct way to use Huber loss
        metrics=['mae', 'mse']
    )
    return model

#  TRAINING WITH CALLBACKS
early_stopping = callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(
    factor=0.5,
    patience=5
)

# Train final score model
score_model = build_enhanced_model(X_train_proc.shape[1], 'score_output')
score_history = score_model.fit(
    X_train_proc, y_score_train,
    epochs=150,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

# Train next over model
over_model = build_enhanced_model(X_train_proc.shape[1], 'over_output')
over_history = over_model.fit(
    X_train_proc, y_next_train,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

#  EVALUATION METRICs

def evaluate_model(model, X_test, y_test, model_name):
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f"\n🔍 {model_name} Evaluation:")
    print(f"MAE: {mae:.2f}")
    print(f"R² Score: {r2:.2f}")
    
    return mae, r2

score_mae, score_r2 = evaluate_model(score_model, X_test_proc, y_score_test, "Final Score Model")
over_mae, over_r2 = evaluate_model(over_model, X_test_proc, y_next_test, "Next Over Runs Model")

score_model.save("enhanced_score_model.keras")
over_model.save("enhanced_next_over_model.keras")
joblib.dump(preprocessor, "enhanced_preprocessor.pkl")

print("\n Models saved successfully!")
# Out:
# Epoch 1/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 53s 19ms/step - loss: 46.1750 - mae: 46.2743 - mse: 4606.9243 - val_loss: 14.9771 - val_mae: 14.8200 - val_mse: 418.8941 - learning_rate: 0.0010
# Epoch 2/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 83s 20ms/step - loss: 18.3699 - mae: 18.1374 - mse: 569.2372 - val_loss: 12.7692 - val_mae: 12.3555 - val_mse: 308.3745 - learning_rate: 0.0010
# Epoch 3/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 83s 20ms/step - loss: 15.8519 - mae: 15.3976 - mse: 423.0517 - val_loss: 12.0678 - val_mae: 11.5035 - val_mse: 266.2339 - learning_rate: 0.0010
# Epoch 4/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 77s 18ms/step - loss: 14.8204 - mae: 14.2320 - mse: 367.5749 - val_loss: 10.8832 - val_mae: 10.2155 - val_mse: 223.1289 - learning_rate: 0.0010
# Epoch 5/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 86s 20ms/step - loss: 14.1948 - mae: 13.5143 - mse: 333.6972 - val_loss: 10.3461 - val_mae: 9.6241 - val_mse: 202.0882 - learning_rate: 0.0010
# Epoch 6/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 77s 18ms/step - loss: 13.4956 - mae: 12.7667 - mse: 302.0319 - val_loss: 9.9680 - val_mae: 9.2058 - val_mse: 190.1243 - learning_rate: 0.0010
# Epoch 7/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 72s 14ms/step - loss: 13.0808 - mae: 12.3179 - mse: 286.0827 - val_loss: 9.5810 - val_mae: 8.8041 - val_mse: 178.3099 - learning_rate: 0.0010
# Epoch 8/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 47s 16ms/step - loss: 12.5881 - mae: 11.8144 - mse: 266.9689 - val_loss: 9.3550 - val_mae: 8.5602 - val_mse: 170.9436 - learning_rate: 0.0010
# Epoch 9/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 92s 20ms/step - loss: 12.2674 - mae: 11.4732 - mse: 255.4867 - val_loss: 9.0126 - val_mae: 8.2013 - val_mse: 159.8802 - learning_rate: 0.0010
# Epoch 10/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━
150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 83s 24ms/step - loss: 4.2291 - mae: 3.9111 - mse: 71.9221 - val_loss: 2.7633 - val_mae: 2.4071 - val_mse: 50.0467 - learning_rate: 2.5000e-04
# Epoch 105/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 83s 25ms/step - loss: 4.1971 - mae: 3.8817 - mse: 72.4824 - val_loss: 2.6897 - val_mae: 2.3307 - val_mse: 47.4678 - learning_rate: 2.5000e-04
# Epoch 106/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 79s 24ms/step - loss: 4.2008 - mae: 3.8883 - mse: 72.2095 - val_loss: 2.7795 - val_mae: 2.4272 - val_mse: 51.3196 - learning_rate: 2.5000e-04
# Epoch 107/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 59s 23ms/step - loss: 4.2134 - mae: 3.9040 - mse: 72.7009 - val_loss: 2.8064 - val_mae: 2.4608 - val_mse: 51.4976 - learning_rate: 2.5000e-04
# Epoch 108/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 4.1897 - mae: 3.8830 - mse: 72.2832 - val_loss: 2.7621 - val_mae: 2.4144 - val_mse: 51.5593 - learning_rate: 2.5000e-04
# Epoch 109/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 4.1912 - mae: 3.8874 - mse: 72.4408 - val_loss: 2.8181 - val_mae: 2.4797 - val_mse: 52.8805 - learning_rate: 2.5000e-04
# Epoch 110/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 4.1822 - mae: 3.8809 - mse: 70.7304 - val_loss: 2.8126 - val_mae: 2.4842 - val_mse: 49.9092 - learning_rate: 2.5000e-04
# Epoch 111/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 4.0424 - mae: 3.7419 - mse: 68.8561 - val_loss: 2.5442 - val_mae: 2.1988 - val_mse: 46.5793 - learning_rate: 1.2500e-04
# Epoch 112/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.8847 - mae: 3.5893 - mse: 63.2685 - val_loss: 2.4972 - val_mae: 2.1553 - val_mse: 45.6394 - learning_rate: 1.2500e-04
# Epoch 113/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.8678 - mae: 3.5806 - mse: 63.0664 - val_loss: 2.5056 - val_mae: 2.1760 - val_mse: 45.4366 - learning_rate: 1.2500e-04
# Epoch 114/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.8486 - mae: 3.5673 - mse: 64.2512 - val_loss: 2.4384 - val_mae: 2.1086 - val_mse: 45.0068 - learning_rate: 1.2500e-04
# Epoch 115/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.8133 - mae: 3.5386 - mse: 62.8089 - val_loss: 2.4605 - val_mae: 2.1365 - val_mse: 45.5389 - learning_rate: 1.2500e-04
# Epoch 116/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.7688 - mae: 3.4993 - mse: 59.2671 - val_loss: 2.4295 - val_mae: 2.1107 - val_mse: 44.4221 - learning_rate: 1.2500e-04
# Epoch 117/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.7681 - mae: 3.5034 - mse: 63.2324 - val_loss: 2.4334 - val_mae: 2.1220 - val_mse: 44.8661 - learning_rate: 1.2500e-04
# Epoch 118/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.7197 - mae: 3.4601 - mse: 59.5162 - val_loss: 2.4338 - val_mae: 2.1255 - val_mse: 45.6270 - learning_rate: 1.2500e-04
# Epoch 119/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.7015 - mae: 3.4464 - mse: 58.2788 - val_loss: 2.4057 - val_mae: 2.1019 - val_mse: 44.5241 - learning_rate: 1.2500e-04
# Epoch 120/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.7282 - mae: 3.4782 - mse: 60.5560 - val_loss: 2.4260 - val_mae: 2.1357 - val_mse: 44.2911 - learning_rate: 1.2500e-04
# Epoch 121/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.7194 - mae: 3.4731 - mse: 62.6186 - val_loss: 2.4302 - val_mae: 2.1356 - val_mse: 46.3600 - learning_rate: 1.2500e-04
# Epoch 122/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.6793 - mae: 3.4368 - mse: 59.1049 - val_loss: 2.3855 - val_mae: 2.0948 - val_mse: 44.7007 - learning_rate: 1.2500e-04
# Epoch 123/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6848 - mae: 3.4472 - mse: 59.8296 - val_loss: 2.3993 - val_mae: 2.1130 - val_mse: 44.7424 - learning_rate: 1.2500e-04
# Epoch 124/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.6774 - mae: 3.4429 - mse: 59.7803 - val_loss: 2.3778 - val_mae: 2.0977 - val_mse: 43.7063 - learning_rate: 1.2500e-04
# Epoch 125/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6857 - mae: 3.4548 - mse: 59.4931 - val_loss: 2.3802 - val_mae: 2.0977 - val_mse: 45.5176 - learning_rate: 1.2500e-04
# Epoch 126/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.6954 - mae: 3.4675 - mse: 62.3671 - val_loss: 2.3911 - val_mae: 2.1202 - val_mse: 44.2328 - learning_rate: 1.2500e-04
# Epoch 127/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6810 - mae: 3.4563 - mse: 61.5635 - val_loss: 2.3452 - val_mae: 2.0711 - val_mse: 43.0746 - learning_rate: 1.2500e-04
# Epoch 128/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 3.6709 - mae: 3.4499 - mse: 60.5489 - val_loss: 2.3554 - val_mae: 2.0835 - val_mse: 44.4958 - learning_rate: 1.2500e-04
# Epoch 129/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6577 - mae: 3.4401 - mse: 59.9183 - val_loss: 2.3609 - val_mae: 2.0926 - val_mse: 45.1637 - learning_rate: 1.2500e-04
# Epoch 130/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6687 - mae: 3.4542 - mse: 58.4248 - val_loss: 2.3238 - val_mae: 2.0570 - val_mse: 43.6932 - learning_rate: 1.2500e-04
# Epoch 131/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.6663 - mae: 3.4544 - mse: 62.2553 - val_loss: 2.3363 - val_mae: 2.0728 - val_mse: 44.1739 - learning_rate: 1.2500e-04
# Epoch 132/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6246 - mae: 3.4150 - mse: 60.8145 - val_loss: 2.3430 - val_mae: 2.0848 - val_mse: 44.0913 - learning_rate: 1.2500e-04
# Epoch 133/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6829 - mae: 3.4769 - mse: 63.7422 - val_loss: 2.3133 - val_mae: 2.0545 - val_mse: 44.2434 - learning_rate: 1.2500e-04
# Epoch 134/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.6618 - mae: 3.4588 - mse: 61.2697 - val_loss: 2.3677 - val_mae: 2.1198 - val_mse: 44.1931 - learning_rate: 1.2500e-04
# Epoch 135/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6521 - mae: 3.4516 - mse: 61.0544 - val_loss: 2.3213 - val_mae: 2.0687 - val_mse: 43.5096 - learning_rate: 1.2500e-04
# Epoch 136/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6054 - mae: 3.4075 - mse: 57.6631 - val_loss: 2.3076 - val_mae: 2.0561 - val_mse: 45.0288 - learning_rate: 1.2500e-04
# Epoch 137/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.6317 - mae: 3.4364 - mse: 60.5988 - val_loss: 2.3119 - val_mae: 2.0651 - val_mse: 44.2327 - learning_rate: 1.2500e-04
# Epoch 138/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6369 - mae: 3.4441 - mse: 62.1051 - val_loss: 2.2966 - val_mae: 2.0533 - val_mse: 43.3666 - learning_rate: 1.2500e-04
# Epoch 139/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6420 - mae: 3.4523 - mse: 60.0260 - val_loss: 2.3191 - val_mae: 2.0770 - val_mse: 44.7058 - learning_rate: 1.2500e-04
# Epoch 140/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.6182 - mae: 3.4302 - mse: 60.4098 - val_loss: 2.3029 - val_mae: 2.0601 - val_mse: 44.7512 - learning_rate: 1.2500e-04
# Epoch 141/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.5843 - mae: 3.3980 - mse: 58.2267 - val_loss: 2.2835 - val_mae: 2.0440 - val_mse: 43.3105 - learning_rate: 1.2500e-04
# Epoch 142/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 3.5967 - mae: 3.4130 - mse: 59.7644 - val_loss: 2.3187 - val_mae: 2.0848 - val_mse: 44.7337 - learning_rate: 1.2500e-04
# Epoch 143/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6154 - mae: 3.4348 - mse: 59.9571 - val_loss: 2.3033 - val_mae: 2.0702 - val_mse: 44.1194 - learning_rate: 1.2500e-04
# Epoch 144/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6172 - mae: 3.4381 - mse: 62.6561 - val_loss: 2.2925 - val_mae: 2.0611 - val_mse: 43.5204 - learning_rate: 1.2500e-04
# Epoch 145/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6029 - mae: 3.4263 - mse: 58.9969 - val_loss: 2.2964 - val_mae: 2.0677 - val_mse: 44.0328 - learning_rate: 1.2500e-04
# Epoch 146/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.5739 - mae: 3.3987 - mse: 58.8758 - val_loss: 2.2809 - val_mae: 2.0561 - val_mse: 44.0628 - learning_rate: 1.2500e-04
# Epoch 147/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6159 - mae: 3.4428 - mse: 62.0122 - val_loss: 2.3074 - val_mae: 2.0811 - val_mse: 44.8976 - learning_rate: 1.2500e-04
# Epoch 148/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6140 - mae: 3.4427 - mse: 60.7428 - val_loss: 2.2316 - val_mae: 2.0054 - val_mse: 43.9038 - learning_rate: 1.2500e-04
# Epoch 149/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.5804 - mae: 3.4114 - mse: 60.9767 - val_loss: 2.2899 - val_mae: 2.0718 - val_mse: 43.9629 - learning_rate: 1.2500e-04
# Epoch 150/150
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 3.6078 - mae: 3.4407 - mse: 61.7904 - val_loss: 2.2705 - val_mae: 2.0493 - val_mse: 44.5639 - learning_rate: 1.2500e-04
# Epoch 1/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - loss: 3.3904 - mae: 3.5873 - mse: 20.9378 - val_loss: 2.9444 - val_mae: 3.2464 - val_mse: 16.7430 - learning_rate: 0.0010
# Epoch 2/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.9690 - mae: 3.2743 - mse: 17.0266 - val_loss: 2.9127 - val_mae: 3.2275 - val_mse: 16.7623 - learning_rate: 0.0010
# Epoch 3/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.9253 - mae: 3.2328 - mse: 16.6393 - val_loss: 2.8917 - val_mae: 3.2022 - val_mse: 16.3112 - learning_rate: 0.0010
# Epoch 4/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.9189 - mae: 3.2208 - mse: 16.5560 - val_loss: 2.8985 - val_mae: 3.1965 - val_mse: 16.5256 - learning_rate: 0.0010
# Epoch 5/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.9078 - mae: 3.1996 - mse: 16.3546 - val_loss: 2.8653 - val_mae: 3.1635 - val_mse: 15.9411 - learning_rate: 0.0010
# Epoch 6/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.8797 - mae: 3.1702 - mse: 16.1587 - val_loss: 2.8842 - val_mae: 3.1739 - val_mse: 16.2717 - learning_rate: 0.0010
# Epoch 7/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.8842 - mae: 3.1696 - mse: 16.1187 - val_loss: 2.8584 - val_mae: 3.1505 - val_mse: 16.0762 - learning_rate: 0.0010
# Epoch 8/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.8488 - mae: 3.1338 - mse: 15.8420 - val_loss: 2.8547 - val_mae: 3.1432 - val_mse: 15.6934 - learning_rate: 0.0010
# Epoch 9/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.8432 - mae: 3.1272 - mse: 15.7830 - val_loss: 2.8330 - val_mae: 3.1266 - val_mse: 15.7881 - learning_rate: 0.0010
# Epoch 10/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.8191 - mae: 3.1087 - mse: 15.6651 - val_loss: 2.8195 - val_mae: 3.1116 - val_mse: 15.4755 - learning_rate: 0.0010
# Epoch 11/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.8131 - mae: 3.1018 - mse: 15.5945 - val_loss: 2.8267 - val_mae: 3.1206 - val_mse: 15.5541 - learning_rate: 0.0010
# Epoch 12/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.8143 - mae: 3.1056 - mse: 15.5826 - val_loss: 2.7981 - val_mae: 3.0941 - val_mse: 15.4160 - learning_rate: 0.0010
# Epoch 13/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.7988 - mae: 3.0910 - mse: 15.4873 - val_loss: 2.7970 - val_mae: 3.0948 - val_mse: 15.2567 - learning_rate: 0.0010
# Epoch 14/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.7877 - mae: 3.0804 - mse: 15.3571 - val_loss: 2.7930 - val_mae: 3.0891 - val_mse: 15.3905 - learning_rate: 0.0010
# Epoch 15/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.7781 - mae: 3.0692 - mse: 15.2789 - val_loss: 2.7791 - val_mae: 3.0750 - val_mse: 15.1576 - learning_rate: 0.0010
# Epoch 16/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.7691 - mae: 3.0610 - mse: 15.2507 - val_loss: 2.7938 - val_mae: 3.0880 - val_mse: 15.6665 - learning_rate: 0.0010
# Epoch 17/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.7617 - mae: 3.0530 - mse: 15.1722 - val_loss: 2.7692 - val_mae: 3.0631 - val_mse: 15.0051 - learning_rate: 0.0010
# Epoch 18/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.7578 - mae: 3.0469 - mse: 15.1365 - val_loss: 2.7742 - val_mae: 3.0687 - val_mse: 15.4299 - learning_rate: 0.0010
# Epoch 19/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.7571 - mae: 3.0491 - mse: 15.1412 - val_loss: 2.7733 - val_mae: 3.0689 - val_mse: 15.0835 - learning_rate: 0.0010
# Epoch 20/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.7431 - mae: 3.0340 - mse: 15.0525 - val_loss: 2.7901 - val_mae: 3.0841 - val_mse: 15.6966 - learning_rate: 0.0010
# Epoch 21/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.7415 - mae: 3.0329 - mse: 15.0382 - val_loss: 2.7784 - val_mae: 3.0738 - val_mse: 15.2949 - learning_rate: 0.0010
# Epoch 22/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.7388 - mae: 3.0307 - mse: 15.0128 - val_loss: 2.7735 - val_mae: 3.0689 - val_mse: 15.4587 - learning_rate: 0.0010
# Epoch 23/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.6815 - mae: 2.9823 - mse: 14.6017 - val_loss: 2.6767 - val_mae: 2.9903 - val_mse: 14.6655 - learning_rate: 5.0000e-04
# Epoch 24/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.6236 - mae: 2.9360 - mse: 14.2960 - val_loss: 2.6617 - val_mae: 2.9792 - val_mse: 14.3588 - learning_rate: 5.0000e-04
# Epoch 25/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5860 - mae: 2.9003 - mse: 13.9950 - val_loss: 2.6387 - val_mae: 2.9566 - val_mse: 14.3685 - learning_rate: 5.0000e-04
# Epoch 26/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.5580 - mae: 2.8725 - mse: 13.8094 - val_loss: 2.6286 - val_mae: 2.9457 - val_mse: 14.2031 - learning_rate: 5.0000e-04
# Epoch 27/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5396 - mae: 2.8528 - mse: 13.6525 - val_loss: 2.6217 - val_mae: 2.9382 - val_mse: 14.1136 - learning_rate: 5.0000e-04
# Epoch 28/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5493 - mae: 2.8618 - mse: 13.7257 - val_loss: 2.6235 - val_mae: 2.9387 - val_mse: 14.2284 - learning_rate: 5.0000e-04
# Epoch 29/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 2.5354 - mae: 2.8464 - mse: 13.6378 - val_loss: 2.6117 - val_mae: 2.9257 - val_mse: 14.0646 - learning_rate: 5.0000e-04
# Epoch 30/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5361 - mae: 2.8468 - mse: 13.5650 - val_loss: 2.6237 - val_mae: 2.9371 - val_mse: 14.0949 - learning_rate: 5.0000e-04
# Epoch 31/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5232 - mae: 2.8323 - mse: 13.4394 - val_loss: 2.6205 - val_mae: 2.9318 - val_mse: 14.1742 - learning_rate: 5.0000e-04
# Epoch 32/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5219 - mae: 2.8296 - mse: 13.4663 - val_loss: 2.6083 - val_mae: 2.9182 - val_mse: 14.0941 - learning_rate: 5.0000e-04
# Epoch 33/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5251 - mae: 2.8325 - mse: 13.4729 - val_loss: 2.6065 - val_mae: 2.9158 - val_mse: 13.9246 - learning_rate: 5.0000e-04
# Epoch 34/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5188 - mae: 2.8252 - mse: 13.3362 - val_loss: 2.6136 - val_mae: 2.9209 - val_mse: 14.0903 - learning_rate: 5.0000e-04
# Epoch 35/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5091 - mae: 2.8132 - mse: 13.3462 - val_loss: 2.6219 - val_mae: 2.9304 - val_mse: 14.1117 - learning_rate: 5.0000e-04
# Epoch 36/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5123 - mae: 2.8153 - mse: 13.3745 - val_loss: 2.6028 - val_mae: 2.9096 - val_mse: 13.8736 - learning_rate: 5.0000e-04
# Epoch 37/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5030 - mae: 2.8065 - mse: 13.2907 - val_loss: 2.6038 - val_mae: 2.9081 - val_mse: 14.0518 - learning_rate: 5.0000e-04
# Epoch 38/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 2.5055 - mae: 2.8074 - mse: 13.2580 - val_loss: 2.6243 - val_mae: 2.9297 - val_mse: 14.0290 - learning_rate: 5.0000e-04
# Epoch 39/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5016 - mae: 2.8018 - mse: 13.2159 - val_loss: 2.6158 - val_mae: 2.9190 - val_mse: 14.1295 - learning_rate: 5.0000e-04
# Epoch 40/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.4936 - mae: 2.7931 - mse: 13.2022 - val_loss: 2.5982 - val_mae: 2.9009 - val_mse: 13.9944 - learning_rate: 5.0000e-04
# Epoch 41/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - loss: 2.4950 - mae: 2.7944 - mse: 13.1513 - val_loss: 2.6153 - val_mae: 2.9181 - val_mse: 14.1783 - learning_rate: 5.0000e-04
# Epoch 42/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.5023 - mae: 2.8014 - mse: 13.2056 - val_loss: 2.6004 - val_mae: 2.9018 - val_mse: 13.8616 - learning_rate: 5.0000e-04
# Epoch 43/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.4901 - mae: 2.7879 - mse: 13.0992 - val_loss: 2.6088 - val_mae: 2.9087 - val_mse: 14.1173 - learning_rate: 5.0000e-04
# Epoch 44/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.4943 - mae: 2.7918 - mse: 13.1581 - val_loss: 2.5949 - val_mae: 2.8951 - val_mse: 13.8407 - learning_rate: 5.0000e-04
# Epoch 45/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.4860 - mae: 2.7824 - mse: 13.0654 - val_loss: 2.5985 - val_mae: 2.8977 - val_mse: 13.7632 - learning_rate: 5.0000e-04
# Epoch 46/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.4911 - mae: 2.7871 - mse: 13.0712 - val_loss: 2.5981 - val_mae: 2.8967 - val_mse: 13.8478 - learning_rate: 5.0000e-04
# Epoch 47/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.4843 - mae: 2.7793 - mse: 13.0654 - val_loss: 2.5990 - val_mae: 2.8976 - val_mse: 13.9410 - learning_rate: 5.0000e-04
# Epoch 48/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.4918 - mae: 2.7872 - mse: 13.1012 - val_loss: 2.6042 - val_mae: 2.9030 - val_mse: 13.9309 - learning_rate: 5.0000e-04
# Epoch 49/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.4901 - mae: 2.7858 - mse: 13.0908 - val_loss: 2.6075 - val_mae: 2.9060 - val_mse: 14.0098 - learning_rate: 5.0000e-04
# Epoch 50/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.4434 - mae: 2.7392 - mse: 12.7737 - val_loss: 2.5470 - val_mae: 2.8521 - val_mse: 13.5416 - learning_rate: 2.5000e-04
# Epoch 51/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.3644 - mae: 2.6657 - mse: 12.2072 - val_loss: 2.5371 - val_mae: 2.8471 - val_mse: 13.4976 - learning_rate: 2.5000e-04
# Epoch 52/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.3684 - mae: 2.6744 - mse: 12.3008 - val_loss: 2.5222 - val_mae: 2.8349 - val_mse: 13.3919 - learning_rate: 2.5000e-04
# Epoch 53/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.3420 - mae: 2.6504 - mse: 12.0882 - val_loss: 2.5093 - val_mae: 2.8243 - val_mse: 13.2923 - learning_rate: 2.5000e-04
# Epoch 54/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.3314 - mae: 2.6421 - mse: 12.0039 - val_loss: 2.5080 - val_mae: 2.8251 - val_mse: 13.3385 - learning_rate: 2.5000e-04
# Epoch 55/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.3412 - mae: 2.6530 - mse: 12.1386 - val_loss: 2.5041 - val_mae: 2.8218 - val_mse: 13.3514 - learning_rate: 2.5000e-04
# Epoch 56/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.3199 - mae: 2.6329 - mse: 11.9783 - val_loss: 2.5039 - val_mae: 2.8235 - val_mse: 13.2746 - learning_rate: 2.5000e-04
# Epoch 57/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.3114 - mae: 2.6250 - mse: 11.9259 - val_loss: 2.5041 - val_mae: 2.8243 - val_mse: 13.3949 - learning_rate: 2.5000e-04
# Epoch 58/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.3054 - mae: 2.6205 - mse: 11.8743 - val_loss: 2.5083 - val_mae: 2.8294 - val_mse: 13.3909 - learning_rate: 2.5000e-04
# Epoch 59/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 2.3076 - mae: 2.6236 - mse: 11.9005 - val_loss: 2.5074 - val_mae: 2.8294 - val_mse: 13.4667 - learning_rate: 2.5000e-04
# Epoch 60/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.3051 - mae: 2.6219 - mse: 11.8695 - val_loss: 2.4983 - val_mae: 2.8211 - val_mse: 13.3202 - learning_rate: 2.5000e-04
# Epoch 61/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.3032 - mae: 2.6205 - mse: 11.8982 - val_loss: 2.4962 - val_mae: 2.8192 - val_mse: 13.3493 - learning_rate: 2.5000e-04
# Epoch 62/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.2916 - mae: 2.6103 - mse: 11.7992 - val_loss: 2.4930 - val_mae: 2.8169 - val_mse: 13.3448 - learning_rate: 2.5000e-04
# Epoch 63/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.3013 - mae: 2.6205 - mse: 11.8687 - val_loss: 2.5029 - val_mae: 2.8266 - val_mse: 13.5056 - learning_rate: 2.5000e-04
# Epoch 64/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.2971 - mae: 2.6160 - mse: 11.8650 - val_loss: 2.4928 - val_mae: 2.8178 - val_mse: 13.3181 - learning_rate: 2.5000e-04
# Epoch 65/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.2939 - mae: 2.6139 - mse: 11.7957 - val_loss: 2.4896 - val_mae: 2.8140 - val_mse: 13.2639 - learning_rate: 2.5000e-04
# Epoch 66/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.2859 - mae: 2.6058 - mse: 11.7316 - val_loss: 2.4918 - val_mae: 2.8165 - val_mse: 13.3344 - learning_rate: 2.5000e-04
# Epoch 67/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.2857 - mae: 2.6058 - mse: 11.7544 - val_loss: 2.4879 - val_mae: 2.8132 - val_mse: 13.2918 - learning_rate: 2.5000e-04
# Epoch 68/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.2926 - mae: 2.6127 - mse: 11.7985 - val_loss: 2.4861 - val_mae: 2.8115 - val_mse: 13.3244 - learning_rate: 2.5000e-04
# Epoch 69/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.2987 - mae: 2.6196 - mse: 11.8390 - val_loss: 2.4975 - val_mae: 2.8234 - val_mse: 13.4043 - learning_rate: 2.5000e-04
# Epoch 70/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.2855 - mae: 2.6063 - mse: 11.7446 - val_loss: 2.4820 - val_mae: 2.8082 - val_mse: 13.2263 - learning_rate: 2.5000e-04
# Epoch 71/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.2871 - mae: 2.6077 - mse: 11.7670 - val_loss: 2.4920 - val_mae: 2.8183 - val_mse: 13.3596 - learning_rate: 2.5000e-04
# Epoch 72/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.2855 - mae: 2.6061 - mse: 11.7623 - val_loss: 2.4922 - val_mae: 2.8169 - val_mse: 13.4306 - learning_rate: 2.5000e-04
# Epoch 73/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.2818 - mae: 2.6019 - mse: 11.7161 - val_loss: 2.4912 - val_mae: 2.8178 - val_mse: 13.3260 - learning_rate: 2.5000e-04
# Epoch 74/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.2818 - mae: 2.6030 - mse: 11.7136 - val_loss: 2.4877 - val_mae: 2.8138 - val_mse: 13.2535 - learning_rate: 2.5000e-04
# Epoch 75/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.2806 - mae: 2.6012 - mse: 11.6927 - val_loss: 2.4898 - val_mae: 2.8162 - val_mse: 13.4038 - learning_rate: 2.5000e-04
# Epoch 76/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.2436 - mae: 2.5644 - mse: 11.4717 - val_loss: 2.4535 - val_mae: 2.7811 - val_mse: 13.0617 - learning_rate: 1.2500e-04
# Epoch 77/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.2039 - mae: 2.5263 - mse: 11.1575 - val_loss: 2.4550 - val_mae: 2.7845 - val_mse: 13.1570 - learning_rate: 1.2500e-04
# Epoch 78/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1868 - mae: 2.5098 - mse: 11.0817 - val_loss: 2.4452 - val_mae: 2.7760 - val_mse: 13.0871 - learning_rate: 1.2500e-04
# Epoch 79/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1947 - mae: 2.5190 - mse: 11.1462 - val_loss: 2.4421 - val_mae: 2.7749 - val_mse: 13.0302 - learning_rate: 1.2500e-04
# Epoch 80/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.1716 - mae: 2.4968 - mse: 10.9908 - val_loss: 2.4350 - val_mae: 2.7688 - val_mse: 13.0008 - learning_rate: 1.2500e-04
# Epoch 81/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1594 - mae: 2.4858 - mse: 10.9104 - val_loss: 2.4404 - val_mae: 2.7741 - val_mse: 13.1230 - learning_rate: 1.2500e-04
# Epoch 82/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1645 - mae: 2.4915 - mse: 10.9362 - val_loss: 2.4336 - val_mae: 2.7689 - val_mse: 13.0110 - learning_rate: 1.2500e-04
# Epoch 83/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.1733 - mae: 2.5015 - mse: 11.0345 - val_loss: 2.4314 - val_mae: 2.7671 - val_mse: 13.0110 - learning_rate: 1.2500e-04
# Epoch 84/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1645 - mae: 2.4929 - mse: 10.9552 - val_loss: 2.4334 - val_mae: 2.7694 - val_mse: 13.0396 - learning_rate: 1.2500e-04
# Epoch 85/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.1633 - mae: 2.4924 - mse: 10.9628 - val_loss: 2.4308 - val_mae: 2.7688 - val_mse: 12.9908 - learning_rate: 1.2500e-04
# Epoch 86/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1692 - mae: 2.4989 - mse: 11.0065 - val_loss: 2.4360 - val_mae: 2.7743 - val_mse: 13.0465 - learning_rate: 1.2500e-04
# Epoch 87/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1403 - mae: 2.4705 - mse: 10.7864 - val_loss: 2.4293 - val_mae: 2.7676 - val_mse: 12.9762 - learning_rate: 1.2500e-04
# Epoch 88/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1598 - mae: 2.4910 - mse: 10.9376 - val_loss: 2.4363 - val_mae: 2.7750 - val_mse: 13.0911 - learning_rate: 1.2500e-04
# Epoch 89/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.1422 - mae: 2.4731 - mse: 10.8262 - val_loss: 2.4331 - val_mae: 2.7730 - val_mse: 13.0354 - learning_rate: 1.2500e-04
# Epoch 90/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1364 - mae: 2.4681 - mse: 10.7554 - val_loss: 2.4291 - val_mae: 2.7695 - val_mse: 13.0176 - learning_rate: 1.2500e-04
# Epoch 91/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1529 - mae: 2.4853 - mse: 10.9274 - val_loss: 2.4313 - val_mae: 2.7711 - val_mse: 13.0762 - learning_rate: 1.2500e-04
# Epoch 92/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.1509 - mae: 2.4840 - mse: 10.9008 - val_loss: 2.4370 - val_mae: 2.7780 - val_mse: 13.1161 - learning_rate: 1.2500e-04
# Epoch 93/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.1400 - mae: 2.4727 - mse: 10.8113 - val_loss: 2.4327 - val_mae: 2.7741 - val_mse: 13.0255 - learning_rate: 1.2500e-04
# Epoch 94/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1410 - mae: 2.4743 - mse: 10.8043 - val_loss: 2.4345 - val_mae: 2.7760 - val_mse: 13.0883 - learning_rate: 1.2500e-04
# Epoch 95/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.1420 - mae: 2.4757 - mse: 10.8587 - val_loss: 2.4350 - val_mae: 2.7771 - val_mse: 13.0555 - learning_rate: 1.2500e-04
# Epoch 96/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1239 - mae: 2.4571 - mse: 10.7628 - val_loss: 2.4162 - val_mae: 2.7585 - val_mse: 12.9461 - learning_rate: 6.2500e-05
# Epoch 97/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.0979 - mae: 2.4313 - mse: 10.5289 - val_loss: 2.4070 - val_mae: 2.7500 - val_mse: 12.9144 - learning_rate: 6.2500e-05
# Epoch 98/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 2.0798 - mae: 2.4133 - mse: 10.4049 - val_loss: 2.4068 - val_mae: 2.7498 - val_mse: 12.9220 - learning_rate: 6.2500e-05
# Epoch 99/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.0752 - mae: 2.4091 - mse: 10.3725 - val_loss: 2.4084 - val_mae: 2.7524 - val_mse: 12.9610 - learning_rate: 6.2500e-05
# Epoch 100/100
# 2559/2559 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.0758 - mae: 2.4104 - mse: 10.3655 - val_loss: 2.4045 - val_mae: 2.7491 - val_mse: 12.9050 - learning_rate: 6.2500e-05
# 1599/1599 ━━━━━━━━━━━━━━━━━━━━ 2s 950us/step
#
# 🔍 Final Score Model Evaluation:
# MAE: 2.02
# R² Score: 0.95
# 1599/1599 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
#
# 🔍 Next Over Runs Model Evaluation:
# MAE: 2.78
# R² Score: 0.26
#
#  Models saved successfully!

# %%
import pandas as pd
import numpy as np
import joblib
import tensorflow as tf
import ipywidgets as widgets
from IPython.display import display, clear_output

# Load dataset
df = pd.read_csv("final_dataset_with_pitch.csv")

# Extract unique options
venues = sorted(df['venue'].dropna().unique())
teams = sorted(df['batting_team'].dropna().unique())
pitch_types = sorted(df['pitch_type'].dropna().unique())

# Initialize widgets with empty options for batter and bowler
venue = widgets.Dropdown(options=venues, description='Venue:')
batting_team = widgets.Dropdown(options=teams, description='Batting:')
bowling_team = widgets.Dropdown(options=teams, description='Bowling:')
batter = widgets.Dropdown(options=[], description='Batter:')
bowler = widgets.Dropdown(options=[], description='Bowler:')
over = widgets.BoundedFloatText(value=5.0, min=0.1, max=20.0, step=0.1, description='Over:')
cumulative_runs = widgets.IntText(value=30, description='Runs:')
cumulative_wickets = widgets.BoundedIntText(value=2, min=0, max=10, description='Wickets:')
pitch_type = widgets.Dropdown(options=pitch_types, description='Pitch:')
predict_button = widgets.Button(description="Predict")
output = widgets.Output()

# Load models and preprocessor
score_model = tf.keras.models.load_model("score_model.keras")
over_model = tf.keras.models.load_model("next_over_model.keras")
preprocessor = joblib.load("preprocessor.pkl")

# Update batter dropdown based on selected batting team
def update_batters(change):
    selected_team = change['new']
    team_batters = sorted(df[df['batting_team'] == selected_team]['batter'].dropna().unique())
    batter.options = team_batters

# Update bowler dropdown based on selected bowling team
def update_bowlers(change):
    selected_team = change['new']
    team_bowlers = sorted(df[df['bowling_team'] == selected_team]['bowler'].dropna().unique())
    bowler.options = team_bowlers

# Attach observers
batting_team.observe(update_batters, names='value')
bowling_team.observe(update_bowlers, names='value')

# Initial trigger to populate batter/bowler on app load
update_batters({'new': batting_team.value})
update_bowlers({'new': bowling_team.value})

# Prediction function
def predict(b):
    with output:
        clear_output()

        try:
            over_val = over.value
            run_rate = cumulative_runs.value / over_val if over_val > 0 else 0.0

            # Determine phase
            if over_val <= 6:
                phase = 'Powerplay'
            elif over_val <= 15:
                phase = 'Middle'
            else:
                phase = 'Death'

            # Prepare input
            input_df = pd.DataFrame([{
                'venue': venue.value,
                'batting_team': batting_team.value,
                'bowling_team': bowling_team.value,
                'batter': batter.value,
                'bowler': bowler.value,
                'over': over_val,
                'cumulative_runs': cumulative_runs.value,
                'cumulative_wickets': cumulative_wickets.value,
                'run_rate': run_rate,
                'phase': phase,
                'pitch_type': pitch_type.value
            }])

            # Transform and predict
            X = preprocessor.transform(input_df)
            score_pred = score_model.predict(X, verbose=0)[0][0]
            over_pred = over_model.predict(X, verbose=0)[0][0]

            print(f"🏏 Predicted Final Score: {score_pred:.2f}")
            print(f"🔁 Predicted Runs in Next Over: {over_pred:.2f}")
        except Exception as e:
            print(f"❌ Error: {e}")

# Bind button
predict_button.on_click(predict)

# Display widgets
display(
    venue, batting_team, bowling_team,
    batter, bowler, over, cumulative_runs,
    cumulative_wickets, pitch_type,
    predict_button, output
)
# Out:
# D:\score prediction2\scoreenv\Lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 8 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Dropdown(description='Venue:', options=('Arun Jaitley Stadium', 'Arun Jaitley Stadium, Delhi', 'Barabati Stadi…
# Dropdown(description='Batting:', options=('Chennai Super Kings', 'Deccan Chargers', 'Delhi Capitals', 'Delhi D…
# Dropdown(description='Bowling:', options=('Chennai Super Kings', 'Deccan Chargers', 'Delhi Capitals', 'Delhi D…
# Dropdown(description='Batter:', options=('A Flintoff', 'A Mukund', 'A Nehra', 'AM Rahane', 'AS Rajpoot', 'AT R…
# Dropdown(description='Bowler:', options=('A Flintoff', 'A Nehra', 'AF Milne', 'AS Rajpoot', 'Akash Singh', 'B …
# BoundedFloatText(value=5.0, description='Over:', max=20.0, min=0.1, step=0.1)
# IntText(value=30, description='Runs:')
# BoundedIntText(value=2, description='Wickets:', max=10)
# Dropdown(description='Pitch:', options=('Balanced', 'Batting-friendly', 'Sluggish', 'Spin-friendly', 'Unknown'…
# Button(description='Predict', style=ButtonStyle())
# Output()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers, constraints
from tensorflow.keras.losses import Huber
import joblib

# Load dataset
df = pd.read_csv("final_dataset_with_pitch.csv")

# Enhanced Feature Engineering
df = df.sort_values(by=['match_id', 'inning', 'over', 'ball'])
df['cumulative_runs'] = df.groupby(['match_id', 'inning'])['total_runs'].cumsum()
df['cumulative_wickets'] = df.groupby(['match_id', 'inning'])['is_wicket'].cumsum()
df['balls_bowled'] = df.groupby(['match_id', 'inning']).cumcount() + 1
df['run_rate'] = df['cumulative_runs'] / (df['over'] + 0.1)
df['strike_rate'] = df.groupby(['match_id', 'inning', 'batter'])['total_runs'].cumsum() / \
                    df.groupby(['match_id', 'inning', 'batter']).cumcount().add(1)

# Player performance metrics
for player_col in ['batter', 'bowler']:
    df[f'{player_col}_avg'] = df.groupby(player_col)['total_runs'].transform(
        lambda x: x.expanding().mean().shift(1)
    )

# Partnership features
df['partnership_runs'] = df.groupby(['match_id', 'inning', 'batter', 'non_striker'])['total_runs'].cumsum()
df['partnership_balls'] = df.groupby(['match_id', 'inning', 'batter', 'non_striker']).cumcount() + 1

# Bowler fatigue metrics
df['bowler_balls_bowled'] = df.groupby(['match_id', 'inning', 'bowler']).cumcount() + 1
df['bowler_recent_economy'] = df.groupby(['match_id', 'inning', 'bowler'])['total_runs'].rolling(12, min_periods=1).mean().reset_index(level=[0,1,2], drop=True)

# Phase
def get_phase(over):
    if over <= 6: return 'Powerplay'
    elif over <= 10: return 'Middle1'
    elif over <= 15: return 'Middle2'
    else: return 'Death'
df['phase'] = df['over'].apply(get_phase)
df['is_death_over'] = (df['over'] >= 16).astype(int)

# Target engineering
final_scores = df.groupby(['match_id', 'inning'])['total_runs'].sum().reset_index()
final_scores.columns = ['match_id', 'inning', 'final_score']
df = pd.merge(df, final_scores, on=['match_id', 'inning'])

def adjust_final_score(row):
    reduction_factors = [0, 0.05, 0.10, 0.20, 0.35, 0.50, 0.65, 0.80, 0.90, 0.95, 1.0]
    return row['final_score'] * (1 - reduction_factors[min(row['cumulative_wickets'], 10)])
df['adjusted_final_score'] = df.apply(adjust_final_score, axis=1)

# Next over runs
MAX_RUNS_PER_OVER = 36
def calculate_next_over_runs(group):
    group = group.sort_values('ball')
    group['next_over_runs'] = np.clip(group['total_runs'].rolling(6).sum().shift(-6), 0, MAX_RUNS_PER_OVER)
    return group
df = df.groupby(['match_id', 'inning', 'over']).apply(calculate_next_over_runs)

# Additional match state features
df['wickets_remaining'] = 10 - df['cumulative_wickets']
df['resources_remaining'] = (20 - df['over']) * (df['wickets_remaining'] / 10)
df['aggression_factor'] = df['run_rate'] * (1 + (df['is_death_over'] * 0.5)) / (df['cumulative_wickets'] + 1)

# Data Cleaning
df.fillna({
    'batter_avg': df['total_runs'].mean(),
    'bowler_avg': df['total_runs'].mean(),
    'next_over_runs': 0,
    'bowler_recent_economy': df['total_runs'].mean()
}, inplace=True)

# Remove outliers
for col in ['total_runs', 'cumulative_runs', 'next_over_runs']:
    q1 = df[col].quantile(0.01)
    q99 = df[col].quantile(0.99)
    df = df[(df[col] >= q1) & (df[col] <= q99)]

# Feature Selection
features = [
    'venue', 'batting_team', 'bowling_team', 'batter', 'bowler',
    'over', 'cumulative_runs', 'cumulative_wickets', 'phase', 'pitch_type',
    'run_rate', 'strike_rate', 'batter_avg', 'bowler_avg',
    'partnership_runs', 'partnership_balls', 'bowler_balls_bowled',
    'bowler_recent_economy', 'wickets_remaining', 'resources_remaining',
    'aggression_factor', 'is_death_over'
]

X = df[features]
y_score = df['adjusted_final_score']
y_next_over = df['next_over_runs']

# Preprocessing
categorical_features = ['venue', 'batting_team', 'bowling_team', 'batter', 'bowler', 'phase', 'pitch_type']
numeric_features = [f for f in features if f not in categorical_features]

preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features),
    ('num', StandardScaler(), numeric_features)
])

# Split
X_train, X_test, y_score_train, y_score_test, y_next_train, y_next_test = train_test_split(
    X, y_score, y_next_over, test_size=0.2, random_state=42, stratify=df['phase']
)

preprocessor.fit(X_train)
X_train_proc = preprocessor.transform(X_train)
X_test_proc = preprocessor.transform(X_test)

# Model
class OverConstraint(constraints.Constraint):
    def __call__(self, w):
        return tf.clip_by_value(w, 0, MAX_RUNS_PER_OVER)

def build_dual_output_model(input_shape):
    inputs = tf.keras.Input(shape=(input_shape,))
    x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
    x = layers.BatchNormalization()(x)

    score_head = layers.Dense(64, activation='relu')(x)
    score_head = layers.Dense(1, name='score_output')(score_head)

    over_head = layers.Dense(64, activation='relu')(x)
    over_head = layers.Dense(1, activation='relu', name='over_output', 
                             kernel_constraint=OverConstraint())(over_head)

    model = tf.keras.Model(inputs=inputs, outputs=[score_head, over_head])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss={'score_output': Huber(), 'over_output': Huber()},
        metrics={'score_output': ['mae', 'mse'], 'over_output': ['mae', 'mse']}
    )
    return model

# Training
early_stopping = callbacks.EarlyStopping(patience=10, restore_best_weights=True)
reduce_lr = callbacks.ReduceLROnPlateau(factor=0.5, patience=5)

model = build_dual_output_model(X_train_proc.shape[1])
model.fit(
    X_train_proc, {'score_output': y_score_train, 'over_output': y_next_train},
    epochs=150,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

# Post-process
def postprocess_predictions(predictions, current_over, wickets_lost):
    final_score, next_over = predictions
    if wickets_lost >= 8:
        final_score *= 0.7
    elif wickets_lost >= 6:
        final_score *= 0.85
    next_over = min(next_over, 25 if current_over >= 18 else 18)
    return final_score, next_over

# Evaluation
def evaluate_model(model, X_test_proc, y_score_test, y_next_test, X_test_raw):
    score_pred, over_pred = model.predict(X_test_proc)
    processed_preds = [
        postprocess_predictions(
            (score_pred[i], over_pred[i]),
            X_test_raw.iloc[i]['over'],
            X_test_raw.iloc[i]['cumulative_wickets']
        ) for i in range(len(X_test_raw))
    ]
    score_pred_adj = np.array([x[0] for x in processed_preds])
    over_pred_adj = np.array([x[1] for x in processed_preds])
    score_mae = mean_absolute_error(y_score_test, score_pred_adj)
    score_r2 = r2_score(y_score_test, score_pred_adj)
    over_mae = mean_absolute_error(y_next_test, over_pred_adj)
    over_r2 = r2_score(y_next_test, over_pred_adj)
    print("Evaluation Results:")
    print(f"Final Score Prediction -> MAE: {score_mae:.2f} | R²: {score_r2:.2f}")
    print(f"Next Over Run Prediction -> MAE: {over_mae:.2f} | R²: {over_r2:.2f}")
    return score_mae, score_r2, over_mae, over_r2

evaluate_model(model, X_test_proc, y_score_test, y_next_test, X_test_raw=X_test)

# Save
model.save("enhanced_dual_model.keras")
joblib.dump(preprocessor, "enhanced_preprocessor.pkl")

# Prediction wrapper
def predict_match_state(input_features):
    processed = preprocessor.transform(input_features)
    score_pred, over_pred = model.predict(processed)
    current_over = input_features['over'].values[0]
    wickets_lost = input_features['cumulative_wickets'].values[0]
    final_score, next_over = postprocess_predictions(
        (score_pred[0][0], over_pred[0][0]), current_over, wickets_lost
    )
    return {
        'predicted_final_score': round(float(final_score), 2),
        'predicted_next_over': round(float(next_over), 2)
    }
# Out:
# C:\Users\Priya\AppData\Local\Temp\ipykernel_19824\396359844.py:64: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['match_id', 'inning', 'over']).apply(calculate_next_over_runs)
# Epoch 1/150
# 2557/2557 ━━━━━━━━━━━━━━━━━━━━ 50s 18ms/step - loss: 35.1081 - over_output_loss: 0.2196 - over_output_mae: 0.3005 - over_output_mse: 1.3249 - score_output_loss: 34.4903 - score_output_mae: 34.9853 - score_output_mse: 2935.3337 - val_loss: 13.3632 - val_over_output_loss: 0.1474 - val_over_output_mae: 0.
150
# 2557/2557 ━━━━━━━━━━━━━━━━━━━━ 67s 26ms/step - loss: 3.9912 - over_output_loss: 0.1525 - over_output_mae: 0.1658 - over_output_mse: 1.1899 - score_output_loss: 3.1771 - score_output_mae: 3.6333 - score_output_mse: 47.7934 - val_loss: 2.8165 - val_over_output_loss: 0.1474 - val_over_output_mae: 0.1606 - val_over_output_mse: 1.1440 - val_score_output_loss: 2.0071 - val_score_output_mae: 2.4408 - val_score_output_mse: 31.7887 - learning_rate: 3.1250e-05
# Epoch 149/150
# 2557/2557 ━━━━━━━━━━━━━━━━━━━━ 71s 28ms/step - loss: 3.9983 - over_output_loss: 0.1495 - over_output_mae: 0.1625 - over_output_mse: 1.1718 - score_output_loss: 3.1884 - score_output_mae: 3.6444 - score_output_mse: 50.6559 - val_loss: 2.7939 - val_over_output_loss: 0.1474 - val_over_output_mae: 0.1606 - val_over_output_mse: 1.1440 - val_score_output_loss: 1.9852 - val_score_output_mae: 2.4176 - val_score_output_mse: 31.5394 - learning_rate: 1.5625e-05
# Epoch 150/150
# 2557/2557 ━━━━━━━━━━━━━━━━━━━━ 79s 31ms/step - loss: 3.9563 - over_output_loss: 0.1486 - over_output_mae: 0.1616 - over_output_mse: 1.1526 - score_output_loss: 3.1481 - score_output_mae: 3.6042 - score_output_mse: 47.3267 - val_loss: 2.7740 - val_over_output_loss: 0.1474 - val_over_output_mae: 0.1606 - val_over_output_mse: 1.1440 - val_score_output_loss: 1.9662 - val_score_output_mae: 2.3977 - val_score_output_mse: 31.1863 - learning_rate: 1.5625e-05
# 1598/1598 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step
# Evaluation Results:
# Final Score Prediction -> MAE: 2.72 | R²: 0.98
# Next Over Run Prediction -> MAE: 0.15 | R²: -0.02

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
from tensorflow.keras import layers, models, callbacks, regularizers, constraints
from tensorflow.keras.losses import Huber
import tensorflow as tf
import joblib

# Load dataset
df = pd.read_csv("final_dataset_with_pitch.csv")
df = df.sort_values(by=['match_id', 'inning', 'over', 'ball'])

# Feature Engineering
df['cumulative_runs'] = df.groupby(['match_id', 'inning'])['total_runs'].cumsum()
df['cumulative_wickets'] = df.groupby(['match_id', 'inning'])['is_wicket'].cumsum()
df['balls_bowled'] = df.groupby(['match_id', 'inning']).cumcount() + 1
df['run_rate'] = df['cumulative_runs'] / (df['over'] + 0.1)
df['strike_rate'] = df.groupby(['match_id', 'inning', 'batter'])['total_runs'].cumsum() / \
                    df.groupby(['match_id', 'inning', 'batter']).cumcount().add(1)

# Player stats
for col in ['batter', 'bowler']:
    df[f'{col}_avg'] = df.groupby(col)['total_runs'].transform(lambda x: x.expanding().mean().shift(1))

# Partnership & bowler economy
df['partnership_runs'] = df.groupby(['match_id', 'inning', 'batter', 'non_striker'])['total_runs'].cumsum()
df['partnership_balls'] = df.groupby(['match_id', 'inning', 'batter', 'non_striker']).cumcount() + 1
df['bowler_balls_bowled'] = df.groupby(['match_id', 'inning', 'bowler']).cumcount() + 1
df['bowler_recent_economy'] = df.groupby(['match_id', 'inning', 'bowler'])['total_runs']\
                                .rolling(12, min_periods=1).mean().reset_index(level=[0,1,2], drop=True)

# Phase encoding
df['phase'] = df['over'].apply(lambda x: 'Powerplay' if x <= 6 else 'Middle1' if x <= 10 else 'Middle2' if x <= 15 else 'Death')
df['is_death_over'] = (df['over'] >= 16).astype(int)

# Target variable engineering
final_scores = df.groupby(['match_id', 'inning'])['total_runs'].sum().reset_index()
final_scores.columns = ['match_id', 'inning', 'final_score']
df = pd.merge(df, final_scores, on=['match_id', 'inning'])

# Adjust final score based on wickets
reduction_factors = [0, 0.05, 0.10, 0.20, 0.35, 0.50, 0.65, 0.80, 0.90, 0.95, 1.0]
df['adjusted_final_score'] = df.apply(
    lambda row: row['final_score'] * (1 - reduction_factors[min(row['cumulative_wickets'], 10)]), axis=1
)

# Predicting next over runs using 6-ball rolling window
def calculate_next_over_runs(group):
    group = group.sort_values('ball')
    group['next_over_runs'] = group['total_runs'].rolling(6).sum().shift(-6)
    return group

df = df.groupby(['match_id', 'inning', 'over'], group_keys=False).apply(calculate_next_over_runs)

# Match state features
df['wickets_remaining'] = 10 - df['cumulative_wickets']
df['resources_remaining'] = (20 - df['over']) * (df['wickets_remaining'] / 10)
df['aggression_factor'] = df['run_rate'] * (1 + 0.5 * df['is_death_over']) / (df['cumulative_wickets'] + 1)

# Handle missing values
df.fillna({
    'batter_avg': df['total_runs'].mean(),
    'bowler_avg': df['total_runs'].mean(),
    'next_over_runs': 0,
    'bowler_recent_economy': df['total_runs'].mean()
}, inplace=True)

# Remove outliers
for col in ['total_runs', 'cumulative_runs', 'next_over_runs']:
    q1, q99 = df[col].quantile([0.01, 0.99])
    df = df[(df[col] >= q1) & (df[col] <= q99)]

# Features
features = [
    'venue', 'batting_team', 'bowling_team', 'batter', 'bowler', 'over', 'cumulative_runs',
    'cumulative_wickets', 'phase', 'pitch_type', 'run_rate', 'strike_rate', 'batter_avg',
    'bowler_avg', 'partnership_runs', 'partnership_balls', 'bowler_balls_bowled',
    'bowler_recent_economy', 'wickets_remaining', 'resources_remaining',
    'aggression_factor', 'is_death_over'
]

X = df[features]
y_score = df['adjusted_final_score']
y_next = df['next_over_runs']

# Preprocessing
categorical = ['venue', 'batting_team', 'bowling_team', 'batter', 'bowler', 'phase', 'pitch_type']
numerical = [f for f in features if f not in categorical]

preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical),
    ('num', StandardScaler(), numerical)
])

# Train/test split
X_train, X_test, y_score_train, y_score_test, y_next_train, y_next_test = train_test_split(
    X, y_score, y_next, test_size=0.2, stratify=df['phase'], random_state=42
)

preprocessor.fit(X_train)
X_train_proc = preprocessor.transform(X_train)
X_test_proc = preprocessor.transform(X_test)

# Custom constraint
MAX_RUNS_PER_OVER = 36
class OverConstraint(constraints.Constraint):
    def __call__(self, w): return tf.clip_by_value(w, 0, MAX_RUNS_PER_OVER)

# Model builder
def build_dual_output_model(input_shape):
    inputs = tf.keras.Input(shape=(input_shape,))
    x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
    x = layers.BatchNormalization()(x)

    score_head = layers.Dense(64, activation='relu')(x)
    score_head = layers.Dense(1, name='score_output')(score_head)

    over_head = layers.Dense(64, activation='relu')(x)
    over_head = layers.Dense(1, activation='relu', name='over_output', kernel_constraint=OverConstraint())(over_head)

    model = models.Model(inputs=inputs, outputs=[score_head, over_head])
    model.compile(
        optimizer='adam',
        loss={'score_output': Huber(), 'over_output': Huber()},
        metrics={'score_output': ['mae', 'mse'], 'over_output': ['mae', 'mse']}
    )
    return model

# Train model
model = build_dual_output_model(X_train_proc.shape[1])
model.fit(
    X_train_proc,
    {'score_output': y_score_train, 'over_output': y_next_train},
    validation_split=0.2,
    epochs=300,
    batch_size=32,
    callbacks=[
        callbacks.EarlyStopping(patience=10, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
    ],
    verbose=1
)

# Postprocessing
def postprocess_predictions(preds, over, wickets):
    score, next_over = preds
    score = score * 0.85 if wickets >= 6 else score * 0.7 if wickets >= 8 else score
    next_over = min(next_over, 25 if over >= 18 else 18)
    return score, next_over

# Evaluation
def evaluate_model(model, X_test_proc, y_score_test, y_next_test, X_test_raw):
    score_preds, over_preds = model.predict(X_test_proc, verbose=0)
    post_preds = [postprocess_predictions((score_preds[i], over_preds[i]), 
                                          X_test_raw.iloc[i]['over'], 
                                          X_test_raw.iloc[i]['cumulative_wickets']) 
                  for i in range(len(X_test_raw))]

    score_final = np.array([x[0] for x in post_preds])
    over_final = np.array([x[1] for x in post_preds])

    print(f"Final Score -> MAE: {mean_absolute_error(y_score_test, score_final):.2f}, R²: {r2_score(y_score_test, score_final):.2f}")
    print(f"Next Over  -> MAE: {mean_absolute_error(y_next_test, over_final):.2f}, R²: {r2_score(y_next_test, over_final):.2f}")

evaluate_model(model, X_test_proc, y_score_test, y_next_test, X_test)

# Save model & preprocessor
model.save("enhanced_dual_model.keras")
joblib.dump(preprocessor, "enhanced_preprocessor.pkl")

# Wrapper for inference
def predict_match_state(input_df):
    proc = preprocessor.transform(input_df)
    score_pred, over_pred = model.predict(proc, verbose=0)
    current_over = input_df['over'].values[0]
    wickets = input_df['cumulative_wickets'].values[0]
    final, over = postprocess_predictions((score_pred[0][0], over_pred[0][0]), current_over, wickets)
    return {'predicted_final_score': round(final, 2), 'predicted_next_over': round(over, 2)}
# Out:
# C:\Users\Priya\AppData\Local\Temp\ipykernel_17192\1526018771.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['match_id', 'inning', 'over'], group_keys=False).apply(calculate_next_over_runs)
# Epoch 1/300
# 5114/5114 ━━━━━━━━━━━━━━━━━━━━ 22s 4ms/step - loss: 29.9049 - over_output_loss: 0.1887 - over_output_mae: 0.2502 - over_output_mse: 1.2192 - score_output_loss: 29.2445 - score_output_mae: 29.7391 - score_output_mse: 2173.0256 - val_loss: 13.8003 - val_over_output_loss: 0.1476 - val_over_output_mae: 0.1611 - val_over_output_mse: 1.1443 - val_score_output_loss: 12.8684 - val_score_output_mae: 13.3567 - val_score_output_mse: 374.4094 - learning_rate: 0.0010
# Epoch 2/300
# 5114/5114 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 15.8301 - over_output_loss: 0.1573 - over_output_mae: 0.1708 - over_output_mse: 1.2437 - score_output_loss: 14.8264 - score_output_mae: 15.3183 - score_output_mse: 448.2397 - val_loss: 12.5726 - val_over_output_loss: 0.1475 - val_over_output_mae: 0.1606 - val_over_output_mse: 1.1440 - val_score_output_loss: 11.4475 - val_score_output_mae: 11.9313 - val_score_output_mse: 322.8271 - learning_rate: 0.0010
# Epoch 3/300
# 5114/5114 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 14.3296 - over_output_loss: 0.1449 - over_output_mae: 0.1577 - over_output_mse: 1.1283 - score_output_loss: 13.1681 - score_output_mae: 13.6584 - score_output_mse: 378.0285 - val_loss: 11.8098 - val_over_output_loss: 0.1475 - val_over_output_mae: 0.1606 - val_over_output_mse: 1.1440 - val_score_output_loss: 10.5676 - val_score_output_mae: 11.0507 - val_score_output_mse: 282.1438 - learning_rate: 0.0010
# Epoch 4/300
# 5114/5114 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss:
300
# 5114/5114 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - loss: 5.1048 - over_output_loss: 0.1512 - over_output_mae: 0.1645 - over_output_mse: 1.1668 - score_output_loss: 4.3452 - score_output_mae: 4.8112 - score_output_mse: 76.5706 - val_loss: 3.5771 - val_over_output_loss: 0.1475 - val_over_output_mae: 0.1606 - val_over_output_mse: 1.1440 - val_score_output_loss: 2.8212 - val_score_output_mae: 3.2710 - val_score_output_mse: 47.5705 - learning_rate: 3.9063e-06
# Epoch 190/300
# 5114/5114 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - loss: 5.1038 - over_output_loss: 0.1502 - over_output_mae: 0.1634 - over_output_mse: 1.1626 - score_output_loss: 4.3454 - score_output_mae: 4.8118 - score_output_mse: 77.8317 - val_loss: 3.5700 - val_over_output_loss: 0.1475 - val_over_output_mae: 0.1606 - val_over_output_mse: 1.1440 - val_score_output_loss: 2.8145 - val_score_output_mae: 3.2643 - val_score_output_mse: 47.3795 - learning_rate: 3.9063e-06
# Epoch 191/300
# 5114/5114 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - loss: 5.0950 - over_output_loss: 0.1488 - over_output_mae: 0.1618 - over_output_mse: 1.1622 - score_output_loss: 4.3381 - score_output_mae: 4.8045 - score_output_mse: 78.1017 - val_loss: 3.5569 - val_over_output_loss: 0.1475 - val_over_output_mae: 0.1606 - val_over_output_mse: 1.1440 - val_score_output_loss: 2.8017 - val_score_output_mae: 3.2512 - val_score_output_mse: 46.8827 - learning_rate: 3.9063e-06
# Final Score -> MAE: 3.49, R²: 0.98
# Next Over  -> MAE: 0.15, R²: -0.02

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers, constraints
from tensorflow.keras.losses import Huber
import joblib

# Load dataset
df = pd.read_csv("final_dataset_with_pitch.csv")

## ENHANCED FEATURE ENGINEERING
df = df.sort_values(by=['match_id', 'inning', 'over', 'ball'])

# Basic cumulative features
df['cumulative_runs'] = df.groupby(['match_id', 'inning'])['total_runs'].cumsum()
df['cumulative_wickets'] = df.groupby(['match_id', 'inning'])['is_wicket'].cumsum()

# Enhanced features with temporal context
df['run_rate'] = df['cumulative_runs'] / (df['over'] + 0.1)
df['strike_rate'] = df.groupby(['match_id', 'inning', 'batter'])['total_runs'].cumsum() / \
                   df.groupby(['match_id', 'inning', 'batter']).cumcount().add(1)

# Player performance metrics with recent form
for player_col in ['batter', 'bowler']:
    df[f'{player_col}_avg'] = df.groupby(player_col)['total_runs'].transform(
        lambda x: x.expanding().mean().shift(1))
    df[f'{player_col}_last5'] = df.groupby(player_col)['total_runs'].transform(
        lambda x: x.rolling(30).mean())

# Partnership dynamics
df['partnership_runs'] = df.groupby(['match_id', 'inning', 'batter', 'non_striker'])['total_runs'].cumsum()
df['partnership_balls'] = df.groupby(['match_id', 'inning', 'batter', 'non_striker']).cumcount() + 1
df['partnership_momentum'] = df['partnership_runs'] / df['partnership_balls']

# Bowler fatigue and recent performance
df['bowler_balls_bowled'] = df.groupby(['match_id', 'inning', 'bowler']).cumcount() + 1
df['bowler_recent_economy'] = df.groupby(['match_id', 'inning', 'bowler'])['total_runs'].rolling(12, min_periods=1).mean().reset_index(level=[0,1,2], drop=True)

# Match phase and pressure indicators
def get_phase(over):
    if over <= 6: return 'Powerplay'
    elif over <= 10: return 'Middle1'
    elif over <= 15: return 'Middle2'
    return 'Death'
df['phase'] = df['over'].apply(get_phase)
df['is_death_over'] = (df['over'] >= 16).astype(int)
df['runs_last_5_overs'] = df.groupby(['match_id', 'inning'])['total_runs'].rolling(30, min_periods=1).sum().reset_index(level=[0,1], drop=True)
df['wickets_last_5_overs'] = df.groupby(['match_id', 'inning'])['is_wicket'].rolling(30, min_periods=1).sum().reset_index(level=[0,1], drop=True)

# Target engineering - improved next over calculation
def calculate_next_over_runs(group):
    group = group.sort_values('ball')
    # Use actual over boundaries instead of rolling window
    over_runs = group.groupby('over')['total_runs'].sum()
    next_over_runs = over_runs.shift(-1)
    group['next_over_runs'] = group['over'].map(next_over_runs)
    return group

df = df.groupby(['match_id', 'inning'], group_keys=False).apply(calculate_next_over_runs)

# Final score target
final_scores = df.groupby(['match_id', 'inning'])['total_runs'].sum().reset_index()
final_scores.columns = ['match_id', 'inning', 'final_score']
df = pd.merge(df, final_scores, on=['match_id', 'inning'])

# Match state features
df['wickets_remaining'] = 10 - df['cumulative_wickets']
df['resources_remaining'] = (20 - df['over']) * (df['wickets_remaining'] / 10)
df['required_run_rate'] = df['final_score'] / (20 - df['over'])
df['run_rate_delta'] = df['run_rate'] - df['required_run_rate']

# DATA CLEANING
df.fillna({
    'batter_avg': df['total_runs'].mean(),
    'bowler_avg': df['total_runs'].mean(),
    'next_over_runs': 0,
    'bowler_recent_economy': df['total_runs'].mean(),
    'batter_last5': df['total_runs'].mean(),
    'bowler_last5': df['total_runs'].mean()
}, inplace=True)

# Remove outliers more carefully
for col in ['total_runs', 'cumulative_runs', 'next_over_runs']:
    q1 = df[col].quantile(0.01)
    q99 = df[col].quantile(0.99)
    df = df[(df[col] >= q1) & (df[col] <= q99)]

# FEATURE SELECTION
features = [
    'venue', 'batting_team', 'bowling_team', 'batter', 'bowler',
    'over', 'cumulative_runs', 'cumulative_wickets', 'phase', 'pitch_type',
    'run_rate', 'strike_rate', 'batter_avg', 'bowler_avg',
    'partnership_runs', 'partnership_balls', 'bowler_balls_bowled',
    'bowler_recent_economy', 'wickets_remaining', 'resources_remaining',
    'is_death_over', 'runs_last_5_overs', 'wickets_last_5_overs',
    'required_run_rate', 'run_rate_delta', 'partnership_momentum',
    'batter_last5', 'bowler_last5'
]

X = df[features]
y_score = df['final_score']
y_next_over = df['next_over_runs']

# PREPROCESSING
categorical_features = ['venue', 'batting_team', 'bowling_team', 'batter', 'bowler', 'phase', 'pitch_type']
numeric_features = [f for f in features if f not in categorical_features]

preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features),
    ('num', StandardScaler(), numeric_features)
])

# TRAIN-TEST SPLIT
X_train, X_test, y_score_train, y_score_test, y_next_train, y_next_test = train_test_split(
    X, y_score, y_next_over, test_size=0.2, random_state=42, stratify=df['phase']
)

# Fit preprocessor
preprocessor.fit(X_train)
X_train_proc = preprocessor.transform(X_train)
X_test_proc = preprocessor.transform(X_test)

## ENHANCED MODEL ARCHITECTURE
class OverConstraint(constraints.Constraint):
    def __call__(self, w):
        return tf.clip_by_value(w, 0, 36)  # Max 36 runs in an over

def build_next_over_model(input_shape):
    inputs = tf.keras.Input(shape=(input_shape,))
    
    # Feature processing
    x = layers.Dense(512, activation='swish', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    
    # Temporal processing
    x = layers.Reshape((1, -1))(x)  # Add temporal dimension
    x = layers.LSTM(128, return_sequences=True)(x)
    x = layers.LSTM(64)(x)
    
    # Final layers
    x = layers.Dense(64, activation='swish')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(1, activation='relu', kernel_constraint=OverConstraint())(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
        loss=Huber(),
        metrics=['mae', 'mse']
    )
    return model

def build_final_score_model(input_shape):
    inputs = tf.keras.Input(shape=(input_shape,))
    
    x = layers.Dense(512, activation='swish', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    
    x = layers.Dense(256, activation='swish')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Dense(128, activation='swish')(x)
    outputs = layers.Dense(1)(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
        loss=Huber(),
        metrics=['mae', 'mse']
    )
    return model

## TRAINING WITH ENHANCED CALLBACKS
class DynamicWeightAdjuster(callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        # Reduce learning rate when validation MAE plateaus
        if logs.get('val_mae') > logs.get('mae') * 1.1:
            lr = tf.keras.backend.get_value(self.model.optimizer.lr)
            tf.keras.backend.set_value(self.model.optimizer.lr, lr * 0.9)

early_stopping = callbacks.EarlyStopping(
    patience=15,
    monitor='val_mae',
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(
    factor=0.5,
    patience=7,
    min_lr=1e-6
)

# Train next over model with sample weighting
over_train_mean = y_next_train.mean()
sample_weights = np.where(y_next_train > over_train_mean, 1.5, 1.0)

over_model = build_next_over_model(X_train_proc.shape[1])
over_history = over_model.fit(
    X_train_proc, y_next_train,
    sample_weight=sample_weights,
    epochs=300,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stopping, reduce_lr, DynamicWeightAdjuster()],
    verbose=1
)

# Train final score model
score_model = build_final_score_model(X_train_proc.shape[1])
score_history = score_model.fit(
    X_train_proc, y_score_train,
    epochs=200,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

## POST-PROCESSING AND EVALUATION
def postprocess_predictions(preds, over, wickets, run_rate, req_rate):
    # Score adjustments
    if wickets >= 8:
        preds *= 0.65  # More aggressive reduction for tailenders
    elif wickets >= 6:
        preds *= 0.8
    
    # Context-based adjustments
    aggression = run_rate / max(req_rate, 1)
    preds = min(preds, 25 if over >= 18 else 18) * aggression
    
    return max(preds, 0)  # Ensure non-negative

def evaluate_model(model, X_test, y_test, model_name, X_test_raw=None):
    y_pred = model.predict(X_test)
    
    if model_name == "Next Over Runs Model" and X_test_raw is not None:
        # Apply post-processing for next over predictions
        y_pred_adj = [
            postprocess_predictions(
                y_pred[i][0],
                X_test_raw.iloc[i]['over'],
                X_test_raw.iloc[i]['cumulative_wickets'],
                X_test_raw.iloc[i]['run_rate'],
                X_test_raw.iloc[i]['required_run_rate']
            )
            for i in range(len(X_test))
        ]
        y_pred = np.array(y_pred_adj).reshape(-1, 1)
    
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f"\n🔍 {model_name} Evaluation:")
    print(f"MAE: {mae:.2f}")
    print(f"R² Score: {r2:.2f}")
    
    return mae, r2

score_mae, score_r2 = evaluate_model(score_model, X_test_proc, y_score_test, "Final Score Model")
over_mae, over_r2 = evaluate_model(over_model, X_test_proc, y_next_test, "Next Over Runs Model", X_test)

# SAVE MODELS
score_model.save("enhanced_score_model.keras")
over_model.save("enhanced_next_over_model.keras")
joblib.dump(preprocessor, "enhanced_preprocessor.pkl")

print("\nModels saved successfully!")
# Out:
# C:\Users\Priya\AppData\Local\Temp\ipykernel_17192\1495747249.py:63: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['match_id', 'inning'], group_keys=False).apply(calculate_next_over_runs)
# Epoch 1/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - loss: 20.3028 - mae: 3.8923 - mse: 24.9413 - val_loss: 4.3472 - val_mae: 3.3946 - val_mse: 18.1086 - learning_rate: 5.0000e-04
# Epoch 2/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.4906 - mae: 3.4516 - mse: 18.8699 - val_loss: 4.4639 - val_mae: 3.3924 - val_mse: 18.2565 - learning_rate: 5.0000e-04
# Epoch 3/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.4631 - mae: 3.4523 - mse: 18.8948 - val_loss: 4.2996 - val_mae: 3.4759 - val_mse: 18.5633 - learning_rate: 5.0000e-04
# Epoch 4/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.4118 - mae: 3.4268 - mse: 18.6335 - val_loss: 4.2511 - val_mae: 3.3211 - val_mse: 17.5781 - learning_rate: 5.0000e-04
# Epoch 5/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.3674 - mae: 3.4223 - mse: 18.6029 - val_loss: 4.2745 - val_mae: 3.3137 - val_mse: 17.6164 - learning_rate: 5.0000e-04
# Epoch 6/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.3306 - mae: 3.4029 - mse: 18.3423 - val_loss: 4.2391 - val_mae: 3.3422 - val_mse: 17.6439 - learning_rate: 5.0000e-04
# Epoch 7/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.3250 - mae: 3.3992 - mse: 18.3681 - val_loss: 4.2091 - val_mae: 3.2996 - val_mse: 17.3575 - learning_rate: 5.0000e-04
# Epoch 8/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2862 - mae: 3.3938 - mse: 18.2741 - val_loss: 4.2136 - val_mae: 3.3134 - val_mse: 17.4211 - learning_rate: 5.0000e-04
# Epoch 9/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2712 - mae: 3.3760 - mse: 18.1330 - val_loss: 4.2173 - val_mae: 3.2812 - val_mse: 17.3217 - learning_rate: 5.0000e-04
# Epoch 10/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.2910 - mae: 3.3846 - mse: 18.2762 - val_loss: 4.2399 - val_mae: 3.3345 - val_mse: 17.6089 - learning_rate: 5.0000e-04
# Epoch 11/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.2760 - mae: 3.3861 - mse: 18.2339 - val_loss: 4.2298 - val_mae: 3.3051 - val_mse: 17.3423 - learning_rate: 5.0000e-04
# Epoch 12/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2840 - mae: 3.3960 - mse: 18.3051 - val_loss: 4.1827 - val_mae: 3.3592 - val_mse: 17.7060 - learning_rate: 5.0000e-04
# Epoch 13/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - loss: 4.2574 - mae: 3.3784 - mse: 18.1696 - val_loss: 4.1950 - val_mae: 3.3452 - val_mse: 17.6025 - learning_rate: 5.0000e-04
# Epoch 14/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2614 - mae: 3.3894 - mse: 18.2058 - val_loss: 4.2709 - val_mae: 3.2675 - val_mse: 17.2581 - learning_rate: 5.0000e-04
# Epoch 15/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - loss: 4.2695 - mae: 3.3859 - mse: 18.2532 - val_loss: 4.1515 - val_mae: 3.3354 - val_mse: 17.4853 - learning_rate: 5.0000e-04
# Epoch 16/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2420 - mae: 3.3763 - mse: 18.1467 - val_loss: 4.1251 - val_mae: 3.2965 - val_mse: 17.2862 - learning_rate: 5.0000e-04
# Epoch 17/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2306 - mae: 3.3772 - mse: 18.1432 - val_loss: 4.1604 - val_mae: 3.2946 - val_mse: 17.3632 - learning_rate: 5.0000e-04
# Epoch 18/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2187 - mae: 3.3688 - mse: 18.0422 - val_loss: 4.1561 - val_mae: 3.3086 - val_mse: 17.3129 - learning_rate: 5.0000e-04
# Epoch 19/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.1999 - mae: 3.3564 - mse: 17.9333 - val_loss: 4.1701 - val_mae: 3.3268 - val_mse: 17.5535 - learning_rate: 5.0000e-04
# Epoch 20/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2139 - mae: 3.3663 - mse: 18.0003 - val_loss: 4.1172 - val_mae: 3.3244 - val_mse: 17.4421 - learning_rate: 5.0000e-04
# Epoch 21/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2309 - mae: 3.3753 - mse: 18.0794 - val_loss: 4.1705 - val_mae: 3.3117 - val_mse: 17.3997 - learning_rate: 5.0000e-04
# Epoch 22/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2219 - mae: 3.3725 - mse: 18.0512 - val_loss: 4.1190 - val_mae: 3.3452 - val_mse: 17.5834 - learning_rate: 5.0000e-04
# Epoch 23/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2272 - mae: 3.3786 - mse: 18.0704 - val_loss: 4.1257 - val_mae: 3.3471 - val_mse: 17.6815 - learning_rate: 5.0000e-04
# Epoch 24/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.1869 - mae: 3.3607 - mse: 17.9799 - val_loss: 4.1544 - val_mae: 3.3552 - val_mse: 17.6067 - learning_rate: 5.0000e-04
# Epoch 25/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.1955 - mae: 3.3582 - mse: 17.9151 - val_loss: 4.1471 - val_mae: 3.3018 - val_mse: 17.3651 - learning_rate: 5.0000e-04
# Epoch 26/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2008 - mae: 3.3612 - mse: 17.9428 - val_loss: 4.1200 - val_mae: 3.3394 - val_mse: 17.5430 - learning_rate: 5.0000e-04
# Epoch 27/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.2126 - mae: 3.3824 - mse: 18.1184 - val_loss: 4.1238 - val_mae: 3.3255 - val_mse: 17.4088 - learning_rate: 5.0000e-04
# Epoch 28/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 3.9415 - mae: 3.3604 - mse: 17.9450 - val_loss: 3.8732 - val_mae: 3.3163 - val_mse: 17.4044 - learning_rate: 2.5000e-04
# Epoch 29/300
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 3.9329 - mae: 3.3544 - mse: 17.8544 - val_loss: 3.8537 - val_mae: 3.2902 - val_mse: 17.1800 - learning_rate: 2.5000e-04
# Epoch 1/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - loss: 63.0990 - mae: 43.3650 - mse: 4248.6519 - val_loss: 12.1200 - val_mae: 7.6418 - val_mse: 102.6358 - learning_rate: 5.0000e-04
# Epoch 2/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - loss: 17.8052 - mae: 13.1837 - mse: 287.6426 - val_loss: 9.3938 - val_mae: 5.0573 - val_mse: 46.9528 - learning_rate: 5.0000e-04
# Epoch 3/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - loss: 15.4811 - mae: 11.4355 - mse: 213.6484 - val_loss: 10.1927 - val_mae: 6.2193 - val_mse: 67.1791 - learning_rate: 5.0000e-04
# Epoch 4/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - loss: 14.4784 - mae: 10.6238 - mse: 183.8326 - val_loss: 8.5541 - val_mae: 4.9287 - val_mse: 44.3488 - learning_rate: 5.0000e-04
# Epoch 5/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - loss: 14.1360 - mae: 10.3202 - mse: 176.1612 - val_loss: 10.8007 - val_mae: 7.2868 - val_mse: 84.6736 - learning_rate: 5.0000e-04
# Epoch 6/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step
200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 9.8694 - mae: 7.4197 - mse: 92.6690 - val_loss: 5.7768 - val_mae: 3.3641 - val_mse: 19.8715 - learning_rate: 5.0000e-04
# Epoch 23/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 9.5828 - mae: 7.1875 - mse: 87.0432 - val_loss: 8.5001 - val_mae: 6.1003 - val_mse: 54.5794 - learning_rate: 5.0000e-04
# Epoch 24/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - loss: 9.5906 - mae: 7.1753 - mse: 86.7177 - val_loss: 6.7050 - val_mae: 4.3674 - val_mse: 31.7525 - learning_rate: 5.0000e-04
# Epoch 25/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - loss: 9.4305 - mae: 7.0579 - mse: 84.3742 - val_loss: 8.4067 - val_mae: 6.0425 - val_mse: 57.0810 - learning_rate: 5.0000e-04
# Epoch 26/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - loss: 9.3583 - mae: 7.0134 - mse: 83.4005 - val_loss: 5.6544 - val_mae: 3.2218 - val_mse: 19.6890 - learning_rate: 5.0000e-04
# Epoch 27/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - loss: 9.3907 - mae: 6.9241 - mse: 81.3283 - val_loss: 5.5011 - val_mae: 3.1283 - val_mse: 18.4237 - learning_rate: 5.0000e-04
# Epoch 28/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - loss: 9.2297 - mae: 6.9008 - mse: 80.5684 - val_loss: 7.3113 - val_mae: 4.9449 - val_mse: 41.5134 - learning_rate: 5.0000e-04
# Epoch 29/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 9.4002 - mae: 6.9991 - mse: 84.1086 - val_loss: 6.1343 - val_mae: 3.8798 - val_mse: 27.2009 - learning_rate: 5.0000e-04
# Epoch 30/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 9.0238 - mae: 6.7264 - mse: 77.0263 - val_loss: 5.7797 - val_mae: 3.4088 - val_mse: 20.1463 - learning_rate: 5.0000e-04
# Epoch 31/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.9589 - mae: 6.6615 - mse: 76.2367 - val_loss: 5.2022 - val_mae: 2.8759 - val_mse: 15.3730 - learning_rate: 5.0000e-04
# Epoch 32/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.8498 - mae: 6.5856 - mse: 74.3128 - val_loss: 5.5602 - val_mae: 3.2572 - val_mse: 20.2785 - learning_rate: 5.0000e-04
# Epoch 33/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.8512 - mae: 6.5641 - mse: 73.8523 - val_loss: 6.0484 - val_mae: 3.7310 - val_mse: 26.2433 - learning_rate: 5.0000e-04
# Epoch 34/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.7266 - mae: 6.4588 - mse: 71.6159 - val_loss: 5.4421 - val_mae: 3.1265 - val_mse: 16.1503 - learning_rate: 5.0000e-04
# Epoch 35/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.7112 - mae: 6.4713 - mse: 72.3600 - val_loss: 5.2223 - val_mae: 2.8974 - val_mse: 15.5280 - learning_rate: 5.0000e-04
# Epoch 36/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.7019 - mae: 6.4320 - mse: 71.3327 - val_loss: 6.6763 - val_mae: 4.4686 - val_mse: 32.0415 - learning_rate: 5.0000e-04
# Epoch 37/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.5320 - mae: 6.3168 - mse: 68.9412 - val_loss: 5.1992 - val_mae: 3.0136 - val_mse: 17.1213 - learning_rate: 5.0000e-04
# Epoch 38/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.5317 - mae: 6.3342 - mse: 69.0701 - val_loss: 5.3117 - val_mae: 3.0735 - val_mse: 17.8093 - learning_rate: 5.0000e-04
# Epoch 39/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.4787 - mae: 6.2695 - mse: 67.4690 - val_loss: 4.9157 - val_mae: 2.7176 - val_mse: 14.3374 - learning_rate: 5.0000e-04
# Epoch 40/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.4321 - mae: 6.2497 - mse: 67.1424 - val_loss: 5.1210 - val_mae: 2.8860 - val_mse: 16.1195 - learning_rate: 5.0000e-04
# Epoch 41/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - loss: 8.3753 - mae: 6.1682 - mse: 65.8041 - val_loss: 5.2335 - val_mae: 3.0326 - val_mse: 16.4478 - learning_rate: 5.0000e-04
# Epoch 42/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.3523 - mae: 6.1682 - mse: 66.0540 - val_loss: 5.8144 - val_mae: 3.6262 - val_mse: 27.1232 - learning_rate: 5.0000e-04
# Epoch 43/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.2854 - mae: 6.0847 - mse: 64.3763 - val_loss: 8.4518 - val_mae: 6.2971 - val_mse: 60.6344 - learning_rate: 5.0000e-04
# Epoch 44/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.2597 - mae: 6.0733 - mse: 63.7715 - val_loss: 5.9671 - val_mae: 3.7714 - val_mse: 29.7459 - learning_rate: 5.0000e-04
# Epoch 45/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.1690 - mae: 5.9826 - mse: 61.9746 - val_loss: 5.3586 - val_mae: 3.1323 - val_mse: 16.6500 - learning_rate: 5.0000e-04
# Epoch 46/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.1320 - mae: 5.9268 - mse: 61.4075 - val_loss: 4.8454 - val_mae: 2.6265 - val_mse: 13.4384 - learning_rate: 5.0000e-04
# Epoch 47/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.2829 - mae: 6.0656 - mse: 64.3887 - val_loss: 4.6845 - val_mae: 2.5178 - val_mse: 12.9087 - learning_rate: 5.0000e-04
# Epoch 48/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.0359 - mae: 5.8753 - mse: 60.1186 - val_loss: 5.0403 - val_mae: 2.8679 - val_mse: 14.7493 - learning_rate: 5.0000e-04
# Epoch 49/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.0053 - mae: 5.8419 - mse: 59.3564 - val_loss: 4.6570 - val_mae: 2.4688 - val_mse: 12.1857 - learning_rate: 5.0000e-04
# Epoch 50/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.0097 - mae: 5.8751 - mse: 60.0562 - val_loss: 7.8123 - val_mae: 5.6467 - val_mse: 45.7484 - learning_rate: 5.0000e-04
# Epoch 51/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.0234 - mae: 5.8865 - mse: 60.3712 - val_loss: 6.5998 - val_mae: 4.4484 - val_mse: 29.8712 - learning_rate: 5.0000e-04
# Epoch 52/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 7.8954 - mae: 5.7476 - mse: 57.8553 - val_loss: 5.0475 - val_mae: 2.9150 - val_mse: 15.9809 - learning_rate: 5.0000e-04
# Epoch 53/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 7.9462 - mae: 5.8008 - mse: 59.1229 - val_loss: 6.1279 - val_mae: 3.9682 - val_mse: 31.0768 - learning_rate: 5.0000e-04
# Epoch 54/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 7.8860 - mae: 5.7369 - mse: 57.8851 - val_loss: 5.8253 - val_mae: 3.6394 - val_mse: 22.9500 - learning_rate: 5.0000e-04
# Epoch 55/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 8.0790 - mae: 5.8439 - mse: 61.0136 - val_loss: 5.6610 - val_mae: 3.5144 - val_mse: 23.2216 - learning_rate: 5.0000e-04
# Epoch 56/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 7.9687 - mae: 5.7676 - mse: 58.2186 - val_loss: 8.6568 - val_mae: 6.5732 - val_mse: 59.8837 - learning_rate: 5.0000e-04
# Epoch 57/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 6.7344 - mae: 5.2712 - mse: 49.0808 - val_loss: 3.8101 - val_mae: 2.4084 - val_mse: 10.9752 - learning_rate: 2.5000e-04
# Epoch 58/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 6.5752 - mae: 5.1955 - mse: 47.8907 - val_loss: 3.4943 - val_mae: 2.0883 - val_mse: 9.4626 - learning_rate: 2.5000e-04
# Epoch 59/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 6.6065 - mae: 5.2153 - mse: 47.9763 - val_loss: 3.4240 - val_mae: 2.0211 - val_mse: 8.2311 - learning_rate: 2.5000e-04
# Epoch 60/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 6.6065 - mae: 5.2122 - mse: 48.1143 - val_loss: 3.2719 - val_mae: 1.8740 - val_mse: 7.5100 - learning_rate: 2.5000e-04
# Epoch 61/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 6.4958 - mae: 5.1124 - mse: 45.7889 - val_loss: 3.3545 - val_mae: 1.9635 - val_mse: 7.8652 - learning_rate: 2.5000e-04
# Epoch 62/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 6.4493 - mae: 5.0738 - mse: 45.3872 - val_loss: 3.6472 - val_mae: 2.2457 - val_mse: 9.8590 - learning_rate: 2.5000e-04
# Epoch 63/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 6.4548 - mae: 5.0920 - mse: 45.6334 - val_loss: 3.3541 - val_mae: 1.9485 - val_mse: 8.8979 - learning_rate: 2.5000e-04
# Epoch 64/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 6.4880 - mae: 5.1136 - mse: 46.1661 - val_loss: 3.8452 - val_mae: 2.4743 - val_mse: 11.7114 - learning_rate: 2.5000e-04
# Epoch 65/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 6.5165 - mae: 5.1478 - mse: 46.5810 - val_loss: 3.7320 - val_mae: 2.3239 - val_mse: 9.5601 - learning_rate: 2.5000e-04
# Epoch 66/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 6.4665 - mae: 5.1001 - mse: 45.8443 - val_loss: 3.2853 - val_mae: 1.9000 - val_mse: 7.6251 - learning_rate: 2.5000e-04
# Epoch 67/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 6.4313 - mae: 5.0703 - mse: 45.4061 - val_loss: 3.2241 - val_mae: 1.8228 - val_mse: 7.1766 - learning_rate: 2.5000e-04
# Epoch 68/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 6.4545 - mae: 5.0873 - mse: 45.4500 - val_loss: 3.8852 - val_mae: 2.4797 - val_mse: 10.5995 - learning_rate: 2.5000e-04
# Epoch 69/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 6.4474 - mae: 5.0768 - mse: 45.5479 - val_loss: 4.7496 - val_mae: 3.3763 - val_mse: 19.7488 - learning_rate: 2.5000e-04
# Epoch 70/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 6.4107 - mae: 5.0503 - mse: 45.4966 - val_loss: 3.3337 - val_mae: 1.9137 - val_mse: 9.0872 - learning_rate: 2.5000e-04
# Epoch 71/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 6.4506 - mae: 5.0671 - mse: 45.6320 - val_loss: 3.5692 - val_mae: 2.1621 - val_mse: 9.2904 - learning_rate: 2.5000e-04
# Epoch 72/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 6.4447 - mae: 5.0783 - mse: 45.8713 - val_loss: 3.7657 - val_mae: 2.3688 - val_mse: 12.5724 - learning_rate: 2.5000e-04
# Epoch 73/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 6.4150 - mae: 5.0552 - mse: 45.3879 - val_loss: 3.7921 - val_mae: 2.4132 - val_mse: 13.4765 - learning_rate: 2.5000e-04
# Epoch 74/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 6.3895 - mae: 5.0203 - mse: 44.6622 - val_loss: 4.7468 - val_mae: 3.3986 - val_mse: 16.5983 - learning_rate: 2.5000e-04
# Epoch 75/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.7604 - mae: 4.7949 - mse: 40.8363 - val_loss: 2.7030 - val_mae: 1.7721 - val_mse: 6.3292 - learning_rate: 1.2500e-04
# Epoch 76/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6518 - mae: 4.7541 - mse: 40.1145 - val_loss: 2.8508 - val_mae: 1.9163 - val_mse: 8.4845 - learning_rate: 1.2500e-04
# Epoch 77/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6421 - mae: 4.7333 - mse: 39.7838 - val_loss: 3.1711 - val_mae: 2.2434 - val_mse: 9.7136 - learning_rate: 1.2500e-04
# Epoch 78/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6485 - mae: 4.7363 - mse: 39.8167 - val_loss: 3.2161 - val_mae: 2.2915 - val_mse: 11.5943 - learning_rate: 1.2500e-04
# Epoch 79/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6214 - mae: 4.7187 - mse: 39.4146 - val_loss: 2.7254 - val_mae: 1.7844 - val_mse: 6.5419 - learning_rate: 1.2500e-04
# Epoch 80/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6927 - mae: 4.7826 - mse: 40.4552 - val_loss: 2.4429 - val_mae: 1.5014 - val_mse: 4.7009 - learning_rate: 1.2500e-04
# Epoch 81/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6434 - mae: 4.7463 - mse: 39.7253 - val_loss: 2.9468 - val_mae: 2.0150 - val_mse: 8.6795 - learning_rate: 1.2500e-04
# Epoch 82/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6297 - mae: 4.7307 - mse: 39.6257 - val_loss: 2.6138 - val_mae: 1.6878 - val_mse: 6.4179 - learning_rate: 1.2500e-04
# Epoch 83/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 41s 9ms/step - loss: 5.6063 - mae: 4.7074 - mse: 39.4015 - val_loss: 2.4602 - val_mae: 1.5191 - val_mse: 5.6700 - learning_rate: 1.2500e-04
# Epoch 84/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6248 - mae: 4.7226 - mse: 39.5164 - val_loss: 2.5969 - val_mae: 1.6538 - val_mse: 5.9886 - learning_rate: 1.2500e-04
# Epoch 85/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 5.6202 - mae: 4.7271 - mse: 39.6763 - val_loss: 2.5581 - val_mae: 1.6208 - val_mse: 6.5199 - learning_rate: 1.2500e-04
# Epoch 86/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 5.5733 - mae: 4.6747 - mse: 38.9949 - val_loss: 2.3677 - val_mae: 1.4240 - val_mse: 5.4063 - learning_rate: 1.2500e-04
# Epoch 87/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.5745 - mae: 4.6737 - mse: 38.4626 - val_loss: 2.5457 - val_mae: 1.6022 - val_mse: 7.6545 - learning_rate: 1.2500e-04
# Epoch 88/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.5409 - mae: 4.6446 - mse: 38.3932 - val_loss: 3.2011 - val_mae: 2.2905 - val_mse: 10.4308 - learning_rate: 1.2500e-04
# Epoch 89/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6095 - mae: 4.7034 - mse: 39.3881 - val_loss: 2.5215 - val_mae: 1.5802 - val_mse: 5.5840 - learning_rate: 1.2500e-04
# Epoch 90/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6007 - mae: 4.7068 - mse: 39.3115 - val_loss: 3.1413 - val_mae: 2.2081 - val_mse: 9.1786 - learning_rate: 1.2500e-04
# Epoch 91/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - loss: 5.5425 - mae: 4.6358 - mse: 38.2541 - val_loss: 2.7725 - val_mae: 1.8226 - val_mse: 7.3714 - learning_rate: 1.2500e-04
# Epoch 92/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.6053 - mae: 4.7013 - mse: 39.2450 - val_loss: 3.3225 - val_mae: 2.4120 - val_mse: 9.9056 - learning_rate: 1.2500e-04
# Epoch 93/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.5208 - mae: 4.6170 - mse: 37.8325 - val_loss: 2.4789 - val_mae: 1.5359 - val_mse: 5.2402 - learning_rate: 1.2500e-04
# Epoch 94/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.2098 - mae: 4.5425 - mse: 37.2987 - val_loss: 2.0768 - val_mae: 1.3989 - val_mse: 5.0032 - learning_rate: 6.2500e-05
# Epoch 95/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - loss: 5.1035 - mae: 4.4922 - mse: 35.8008 - val_loss: 2.2492 - val_mae: 1.5789 - val_mse: 6.5253 - learning_rate: 6.2500e-05
# Epoch 96/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 5.0687 - mae: 4.4494 - mse: 35.2244 - val_loss: 2.4126 - val_mae: 1.7648 - val_mse: 7.3843 - learning_rate: 6.2500e-05
# Epoch 97/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.0618 - mae: 4.4499 - mse: 35.1146 - val_loss: 2.0140 - val_mae: 1.3360 - val_mse: 5.3855 - learning_rate: 6.2500e-05
# Epoch 98/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - loss: 5.0920 - mae: 4.4736 - mse: 35.6628 - val_loss: 1.9484 - val_mae: 1.2618 - val_mse: 4.5316 - learning_rate: 6.2500e-05
# Epoch 99/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 5.0687 - mae: 4.4639 - mse: 35.4512 - val_loss: 1.9651 - val_mae: 1.2959 - val_mse: 3.9310 - learning_rate: 6.2500e-05
# Epoch 100/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 5.0671 - mae: 4.4664 - mse: 35.1959 - val_loss: 2.2005 - val_mae: 1.5471 - val_mse: 5.2951 - learning_rate: 6.2500e-05
# Epoch 101/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - loss: 5.1020 - mae: 4.4959 - mse: 36.1823 - val_loss: 2.2247 - val_mae: 1.5605 - val_mse: 5.5194 - learning_rate: 6.2500e-05
# Epoch 102/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 5.0065 - mae: 4.4022 - mse: 34.6302 - val_loss: 2.1702 - val_mae: 1.5118 - val_mse: 5.7213 - learning_rate: 6.2500e-05
# Epoch 103/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 5.0410 - mae: 4.4361 - mse: 35.0152 - val_loss: 2.2547 - val_mae: 1.5944 - val_mse: 5.9124 - learning_rate: 6.2500e-05
# Epoch 104/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 5.0088 - mae: 4.4055 - mse: 34.3054 - val_loss: 2.0249 - val_mae: 1.3590 - val_mse: 5.8754 - learning_rate: 6.2500e-05
# Epoch 105/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 5.0550 - mae: 4.4557 - mse: 35.4167 - val_loss: 2.1497 - val_mae: 1.4927 - val_mse: 5.4671 - learning_rate: 6.2500e-05
# Epoch 106/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - loss: 4.9008 - mae: 4.4223 - mse: 34.8403 - val_loss: 2.0650 - val_mae: 1.5772 - val_mse: 5.6339 - learning_rate: 3.1250e-05
# Epoch 107/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 42s 10ms/step - loss: 4.7894 - mae: 4.3491 - mse: 33.6253 - val_loss: 1.8880 - val_mae: 1.3882 - val_mse: 4.9306 - learning_rate: 3.1250e-05
# Epoch 108/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.8066 - mae: 4.3710 - mse: 33.8284 - val_loss: 1.8562 - val_mae: 1.3475 - val_mse: 5.7167 - learning_rate: 3.1250e-05
# Epoch 109/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.8522 - mae: 4.4123 - mse: 34.4874 - val_loss: 1.7075 - val_mae: 1.1894 - val_mse: 4.1000 - learning_rate: 3.1250e-05
# Epoch 110/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.7920 - mae: 4.3583 - mse: 33.8790 - val_loss: 1.8397 - val_mae: 1.3267 - val_mse: 4.9872 - learning_rate: 3.1250e-05
# Epoch 111/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.7791 - mae: 4.3421 - mse: 33.7340 - val_loss: 1.9016 - val_mae: 1.4063 - val_mse: 5.3248 - learning_rate: 3.1250e-05
# Epoch 112/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.7890 - mae: 4.3510 - mse: 33.6781 - val_loss: 1.8072 - val_mae: 1.2917 - val_mse: 5.1651 - learning_rate: 3.1250e-05
# Epoch 113/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.7739 - mae: 4.3363 - mse: 33.3986 - val_loss: 1.8770 - val_mae: 1.3788 - val_mse: 5.6940 - learning_rate: 3.1250e-05
# Epoch 114/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.7931 - mae: 4.3628 - mse: 34.1802 - val_loss: 1.8726 - val_mae: 1.3666 - val_mse: 5.2634 - learning_rate: 3.1250e-05
# Epoch 115/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.7750 - mae: 4.3435 - mse: 33.6606 - val_loss: 2.0121 - val_mae: 1.5282 - val_mse: 6.4001 - learning_rate: 3.1250e-05
# Epoch 116/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.7723 - mae: 4.3409 - mse: 33.5426 - val_loss: 1.8037 - val_mae: 1.2948 - val_mse: 4.7505 - learning_rate: 3.1250e-05
# Epoch 117/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.7196 - mae: 4.3567 - mse: 33.8724 - val_loss: 1.7380 - val_mae: 1.3239 - val_mse: 5.1020 - learning_rate: 1.5625e-05
# Epoch 118/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.6490 - mae: 4.3081 - mse: 32.9434 - val_loss: 1.7938 - val_mae: 1.3911 - val_mse: 4.9173 - learning_rate: 1.5625e-05
# Epoch 119/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.5909 - mae: 4.2512 - mse: 32.3570 - val_loss: 1.6987 - val_mae: 1.2670 - val_mse: 5.0643 - learning_rate: 1.5625e-05
# Epoch 120/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.7186 - mae: 4.3808 - mse: 34.4889 - val_loss: 1.7072 - val_mae: 1.2912 - val_mse: 5.3360 - learning_rate: 1.5625e-05
# Epoch 121/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.6483 - mae: 4.3094 - mse: 33.1976 - val_loss: 1.7635 - val_mae: 1.3629 - val_mse: 5.1365 - learning_rate: 1.5625e-05
# Epoch 122/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - loss: 4.6303 - mae: 4.2943 - mse: 32.6598 - val_loss: 1.7348 - val_mae: 1.3357 - val_mse: 4.9315 - learning_rate: 1.5625e-05
# Epoch 123/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.6599 - mae: 4.3238 - mse: 33.3421 - val_loss: 1.5886 - val_mae: 1.1520 - val_mse: 4.2693 - learning_rate: 1.5625e-05
# Epoch 124/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.6627 - mae: 4.3275 - mse: 33.2423 - val_loss: 1.6361 - val_mae: 1.2082 - val_mse: 4.3868 - learning_rate: 1.5625e-05
# Epoch 125/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.6060 - mae: 4.2715 - mse: 32.2626 - val_loss: 1.6661 - val_mae: 1.2413 - val_mse: 5.2539 - learning_rate: 1.5625e-05
# Epoch 126/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.6242 - mae: 4.2911 - mse: 33.1252 - val_loss: 1.6752 - val_mae: 1.2585 - val_mse: 4.9421 - learning_rate: 1.5625e-05
# Epoch 127/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.6686 - mae: 4.3364 - mse: 33.4037 - val_loss: 1.6618 - val_mae: 1.2454 - val_mse: 4.5693 - learning_rate: 1.5625e-05
# Epoch 128/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.6057 - mae: 4.2723 - mse: 32.6049 - val_loss: 1.9127 - val_mae: 1.5312 - val_mse: 6.0157 - learning_rate: 1.5625e-05
# Epoch 129/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.6228 - mae: 4.2917 - mse: 32.7812 - val_loss: 1.7231 - val_mae: 1.3187 - val_mse: 4.7699 - learning_rate: 1.5625e-05
# Epoch 130/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.6175 - mae: 4.2842 - mse: 32.5846 - val_loss: 1.6937 - val_mae: 1.2823 - val_mse: 4.8922 - learning_rate: 1.5625e-05
# Epoch 131/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.5538 - mae: 4.2570 - mse: 32.3381 - val_loss: 1.5893 - val_mae: 1.2138 - val_mse: 4.7087 - learning_rate: 7.8125e-06
# Epoch 132/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.4866 - mae: 4.2019 - mse: 32.0209 - val_loss: 1.6116 - val_mae: 1.2414 - val_mse: 5.1697 - learning_rate: 7.8125e-06
# Epoch 133/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.5497 - mae: 4.2681 - mse: 32.5255 - val_loss: 1.6082 - val_mae: 1.2317 - val_mse: 5.2533 - learning_rate: 7.8125e-06
# Epoch 134/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - loss: 4.5475 - mae: 4.2653 - mse: 32.3446 - val_loss: 1.6337 - val_mae: 1.2764 - val_mse: 4.9197 - learning_rate: 7.8125e-06
# Epoch 135/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.6067 - mae: 4.3263 - mse: 33.2977 - val_loss: 1.6568 - val_mae: 1.3063 - val_mse: 4.8863 - learning_rate: 7.8125e-06
# Epoch 136/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - loss: 4.5825 - mae: 4.3038 - mse: 33.0759 - val_loss: 1.5726 - val_mae: 1.1974 - val_mse: 5.0200 - learning_rate: 7.8125e-06
# Epoch 137/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - loss: 4.5678 - mae: 4.2887 - mse: 32.8580 - val_loss: 1.5783 - val_mae: 1.2134 - val_mse: 4.9031 - learning_rate: 7.8125e-06
# Epoch 138/200
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - loss: 4.5341 - mae: 4.2545 - mse: 32.2796 - val_loss: 1.5498 - val_mae: 1.1728 - val_mse: 4.6368 - learning_rate: 7.8125e-06
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
#
# 🔍 Final Score Model Evaluation:
# MAE: 1.14
# R² Score: 1.00
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
#
# 🔍 Next Over Runs Model Evaluation:
# MAE: 6.54
# R² Score: -13.17
#
# Models saved successfully!

# %%
import pandas as pd
import numpy as np
import joblib
import tensorflow as tf
import ipywidgets as widgets
from IPython.display import display, clear_output

# Load dataset
df = pd.read_csv("final_dataset_with_pitch.csv")

# Extract unique options
venues = sorted(df['venue'].dropna().unique())
teams = sorted(df['batting_team'].dropna().unique())
pitch_types = sorted(df['pitch_type'].dropna().unique())

# Initialize widgets with empty options for batter and bowler
venue = widgets.Dropdown(options=venues, description='Venue:')
batting_team = widgets.Dropdown(options=teams, description='Batting:')
bowling_team = widgets.Dropdown(options=teams, description='Bowling:')
batter = widgets.Dropdown(options=[], description='Batter:')
bowler = widgets.Dropdown(options=[], description='Bowler:')
over = widgets.BoundedFloatText(value=5.0, min=0.1, max=20.0, step=0.1, description='Over:')
cumulative_runs = widgets.IntText(value=30, description='Runs:')
cumulative_wickets = widgets.BoundedIntText(value=2, min=0, max=10, description='Wickets:')
pitch_type = widgets.Dropdown(options=pitch_types, description='Pitch:')
predict_button = widgets.Button(description="Predict")
output = widgets.Output()

# Load models and preprocessor
score_model = tf.keras.models.load_model("score_model.keras")
over_model = tf.keras.models.load_model("next_over_model.keras")
preprocessor = joblib.load("preprocessor.pkl")

# Update batter dropdown based on selected batting team
def update_batters(change):
    selected_team = change['new']
    team_batters = sorted(df[df['batting_team'] == selected_team]['batter'].dropna().unique())
    batter.options = team_batters

# Update bowler dropdown based on selected bowling team
def update_bowlers(change):
    selected_team = change['new']
    team_bowlers = sorted(df[df['bowling_team'] == selected_team]['bowler'].dropna().unique())
    bowler.options = team_bowlers

# Attach observers
batting_team.observe(update_batters, names='value')
bowling_team.observe(update_bowlers, names='value')

# Initial trigger to populate batter/bowler on app load
update_batters({'new': batting_team.value})
update_bowlers({'new': bowling_team.value})

# Prediction function
def predict(b):
    with output:
        clear_output()

        try:
            over_val = over.value
            run_rate = cumulative_runs.value / over_val if over_val > 0 else 0.0

            # Determine phase
            if over_val <= 6:
                phase = 'Powerplay'
            elif over_val <= 15:
                phase = 'Middle'
            else:
                phase = 'Death'

            # Prepare input
            input_df = pd.DataFrame([{
                'venue': venue.value,
                'batting_team': batting_team.value,
                'bowling_team': bowling_team.value,
                'batter': batter.value,
                'bowler': bowler.value,
                'over': over_val,
                'cumulative_runs': cumulative_runs.value,
                'cumulative_wickets': cumulative_wickets.value,
                'run_rate': run_rate,
                'phase': phase,
                'pitch_type': pitch_type.value
            }])

            # Transform and predict
            X = preprocessor.transform(input_df)
            score_pred = score_model.predict(X, verbose=0)[0][0]
            over_pred = over_model.predict(X, verbose=0)[0][0]

            print(f"🏏 Predicted Final Score: {score_pred:.2f}")
            print(f"🔁 Predicted Runs in Next Over: {over_pred:.2f}")
        except Exception as e:
            print(f"❌ Error: {e}")

# Bind button
predict_button.on_click(predict)

# Display widgets
display(
    venue, batting_team, bowling_team,
    batter, bowler, over, cumulative_runs,
    cumulative_wickets, pitch_type,
    predict_button, output
)
# Out:
# D:\score prediction2\scoreenv\Lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 8 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Dropdown(description='Venue:', options=('Arun Jaitley Stadium', 'Arun Jaitley Stadium, Delhi', 'Barabati Stadi…
# Dropdown(description='Batting:', options=('Chennai Super Kings', 'Deccan Chargers', 'Delhi Capitals', 'Delhi D…
# Dropdown(description='Bowling:', options=('Chennai Super Kings', 'Deccan Chargers', 'Delhi Capitals', 'Delhi D…
# Dropdown(description='Batter:', options=('A Flintoff', 'A Mukund', 'A Nehra', 'AM Rahane', 'AS Rajpoot', 'AT R…
# Dropdown(description='Bowler:', options=('A Flintoff', 'A Nehra', 'AF Milne', 'AS Rajpoot', 'Akash Singh', 'B …
# BoundedFloatText(value=5.0, description='Over:', max=20.0, min=0.1, step=0.1)
# IntText(value=30, description='Runs:')
# BoundedIntText(value=2, description='Wickets:', max=10)
# Dropdown(description='Pitch:', options=('Balanced', 'Batting-friendly', 'Sluggish', 'Spin-friendly', 'Unknown'…
# Button(description='Predict', style=ButtonStyle())
# Output()
